# %% [markdown]
# # Introduction: Feature Selector Usage
#
# In this notebook we will walk-through using the `FeatureSelector` class for selecting features to remove from a dataset. This class has five methods for finding features to remove:
#
# 1. Find columns with a missing fraction greater than a specified threshold
# 2. Find features with only a single unique value
# 3. Find collinear features as identified by a correlation coefficient greater than a specified value
# 4. Find features with 0.0 importance from a gradient boosting machine
# 5. Find features that do not contribute to a specified cumulative feature importance from the gradient boosting machine
#
# The FeatureSelector is a work in progress! Any contributions on GitHub are appreciated.

# %%
from feature_selector import FeatureSelector

import pandas as pd

# %% [markdown]
# ## Dataset
# 상위폴더에서 만들어진 preprocessed TCGA dataset -> RNASeqV2.geneExp.df.tsv 파일을 이용한다.
#
# The feature selector was designed to be used for machine learning tasks, but can be applied to any dataset.\ The feature importance based methods do require a supervised machine learning problem.

# %%
data=pd.read_csv('../tiny_data.df.tsv', sep='\t')

# %%
from sklearn.preprocessing import LabelEncoder
train=data
exp = train.set_index('cancer type')

# %%
X = exp.reset_index().drop(['gene_id','cancer type'], axis=1)

y_ = exp.index
lb = LabelEncoder()
lb.fit(y_)
y=lb.transform(y_)

# %%
pd.DataFrame(y_).to_csv('../tiny_labels.tsv', header=True, index=False, sep='\t')

# %%
train_X=X

# %% [markdown]
# # Implementation
#
# The `FeatureSelector` has five functions for identifying columns to remove:
#
# * `identify_missing`
# * `identify_single_unique`
# * `identify_collinear`
# * `identify_zero_importance`
# * `identify_low_importance`
#
# These methods find the features to drop according to specified criteria. The identified features are stored in the `ops` attribute (a Python dictionary) of the `FeatureSelector`. We can remove the identified features manually or use the `remove` function in the  `FeatureSelector` for actually removing the features.

# %% [markdown]
# ### Create the Instance
#
# The `FeatureSelector` only requires a dataset with observations in the rows and features in the columns (standard structured data). We are working with a classifified machine learning problem so we also pass in training labels.

# %%
fs = FeatureSelector(data = train_X, labels = y)

# %% [markdown]
# # 2. Single Unique Value
#
# The next method is straightforward: find any features that have only a single unique value. (This does not one-hot encode the features).

# %%
fs.identify_single_unique()
# Out:
# 254 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
single_unique
# Out:
# ['?|728045',
#  'DEFB106A|245909',
#  'DEFB121|245934',
#  'DEFB128|245939',
#  'DEFB130|245940',
#  'DUX4|22947',
#  'HBII-52-24|100036563',
#  'HBII-52-27|100036564',
#  'HBII-52-28|100036565',
#  'HBII-52-45|100036566',
#  'HBII-52-46|100036567',
#  'KRTAP19-2|337969',
#  'KRTAP20-3|337985',
#  'KRTAP22-1|337979',
#  'LOC653545|653545',
#  'OR5B17|219965',
#  'POM121L12|285877',
#  'PRAMEF3|401940',
#  'PRR20A|122183',
#  'PRR20B|729233',
#  'PRR20D|729246',
#  'RNU5E|26829',
#  'RNY4|6086',
#  'RNY5|6090',
#  'SNAR-A13|100169959',
#  'SNAR-A3|100169951',
#  'SNAR-A4|100169956',
#  'SNAR-C2|100170218',
#  'SNAR-C3|100170226',
#  'SNAR-H|100170221',
#  'SNORA11C|100124540',
#  'SNORA35|677816',
#  'SNORA70C|100124538',
#  'SNORD102|26771',
#  'SNORD104|692227',
#  'SNORD105B|100113382',
#  'SNORD105|692229',
#  'SNORD109B|338429',
#  'SNORD110|692213',
#  'SNORD111B|100113402',
#  'SNORD111|692214',
#  'SNORD113-1|767561',
#  'SNORD113-2|767562',
#  'SNORD113-4|767564',
#  'SNORD113-5|767565',
#  'SNORD113-6|767566',
#  'SNORD113-7|767567',
#  'SNORD113-9|767569',
#  'SNORD114-10|767588',
#  'SNORD114-11|767589',
#  'SNORD114-12|767590',
#  'SNORD114-13|767591',
#  'SNORD114-14|767592',
#  'SNORD114-15|767593',
#  'SNORD114-16|767594',
#  'SNORD114-17|767595',
#  'SNORD114-18|767596',
#  'SNORD114-19|767597',
#  'SNORD114-1|767577',
#  'SNORD114-20|767598',
#  'SNORD114-21|767599',
#  'SNORD114-22|767600',
#  'SNORD114-23|767603',
#  'SNORD114-24|767604',
#  'SNORD114-25|767605',
#  'SNORD114-26|767606',
#  'SNORD114-27|767608',
#  'SNORD114-28|767609',
#  'SNORD114-29|767610',
#  'SNORD114-2|767578',
#  'SNORD114-30|767611',
#  'SNORD114-31|767612',
#  'SNORD114-3|767579',
#  'SNORD114-4|767580',
#  'SNORD114-5|767581',
#  'SNORD114-6|767582',
#  'SNORD114-7|767583',
#  'SNORD114-8|767584',
#  'SNORD114-9|767585',
#  'SNORD115-10|100033447',
#  'SNORD115-11|100033448',
#  'SNORD115-14|100033451',
#  'SNORD115-16|100033454',
#  'SNORD115-17|100033455',
#  'SNORD115-1|338433',
#  'SNORD115-20|100033460',
#  'SNORD115-22|100033799',
#  'SNORD115-25|100033801',
#  'SNORD115-2|100033437',
#  'SNORD115-30|100033804',
#  'SNORD115-31|100033805',
#  'SNORD115-32|100033806',
#  'SNORD115-33|100033807',
#  'SNORD115-35|100033809',
#  'SNORD115-37|100033811',
#  'SNORD115-38|100033812',
#  'SNORD115-39|100033813',
#  'SNORD115-3|100033440',
#  'SNORD115-40|100033814',
#  'SNORD115-41|100033815',
#  'SNORD115-44|100033818',
#  'SNORD115-48|100033822',
#  'SNORD115-4|100033441',
#  'SNORD115-5|100033442',
#  'SNORD115-6|100033443',
#  'SNORD115-8|100033445',
#  'SNORD115-9|100033446',
#  'SNORD116-10|100033422',
#  'SNORD116-11|100033423',
#  'SNORD116-12|100033424',
#  'SNORD116-13|100033425',
#  'SNORD116-14|100033426',
#  'SNORD116-15|100033427',
#  'SNORD116-16|100033428',
#  'SNORD116-18|100033430',
#  'SNORD116-19|727708',
#  'SNORD116-1|100033413',
#  'SNORD116-22|100033433',
#  'SNORD116-23|100033434',
#  'SNORD116-24|100033435',
#  'SNORD116-25|100033436',
#  'SNORD116-26|100033438',
#  'SNORD116-27|100033439',
#  'SNORD116-29|100033821',
#  'SNORD116-2|100033414',
#  'SNORD116-3|100033415',
#  'SNORD116-5|100033417',
#  'SNORD116-8|100033420',
#  'SNORD117|692233',
#  'SNORD119|100113378',
#  'SNORD11B|100113392',
#  'SNORD11|692058',
#  'SNORD121A|100113379',
#  'SNORD121B|100113385',
#  'SNORD123|100113384',
#  'SNORD124|100113390',
#  'SNORD125|100113380',
#  'SNORD126|100113391',
#  'SNORD127|100113389',
#  'SNORD12B|100113393',
#  'SNORD12C|26765',
#  'SNORD12|692057',
#  'SNORD16|595097',
#  'SNORD18A|595098',
#  'SNORD18B|595099',
#  'SNORD18C|595100',
#  'SNORD19B|100113381',
#  'SNORD19|692089',
#  'SNORD1A|677848',
#  'SNORD1B|677849',
#  'SNORD20|6082',
#  'SNORD21|6083',
#  'SNORD24|26820',
#  'SNORD25|9303',
#  'SNORD26|9302',
#  'SNORD27|9301',
#  'SNORD28|9300',
#  'SNORD29|9297',
#  'SNORD2|619567',
#  'SNORD30|9299',
#  'SNORD31|9298',
#  'SNORD32A|26819',
#  'SNORD32B|692092',
#  'SNORD33|26818',
#  'SNORD34|26817',
#  'SNORD35A|26816',
#  'SNORD35B|84546',
#  'SNORD36A|26815',
#  'SNORD36B|26814',
#  'SNORD36C|26813',
#  'SNORD37|26812',
#  'SNORD38A|94162',
#  'SNORD38B|94163',
#  'SNORD41|26810',
#  'SNORD42A|26809',
#  'SNORD42B|26808',
#  'SNORD43|26807',
#  'SNORD44|26806',
#  'SNORD45A|26805',
#  'SNORD45B|26804',
#  'SNORD45C|692085',
#  'SNORD46|94161',
#  'SNORD47|26802',
#  'SNORD48|26801',
#  'SNORD49A|26800',
#  'SNORD49B|692087',
#  'SNORD4A|26773',
#  'SNORD4B|26772',
#  'SNORD50A|26799',
#  'SNORD50B|692088',
#  'SNORD51|26798',
#  'SNORD52|26797',
#  'SNORD53|26796',
#  'SNORD54|26795',
#  'SNORD55|26811',
#  'SNORD56B|319139',
#  'SNORD56|26793',
#  'SNORD57|26792',
#  'SNORD58A|26791',
#  'SNORD58C|100124516',
#  'SNORD59A|26789',
#  'SNORD59B|692090',
#  'SNORD5|692072',
#  'SNORD60|26788',
#  'SNORD61|26787',
#  'SNORD62A|26786',
#  'SNORD63|26785',
#  'SNORD65|692106',
#  'SNORD66|692107',
#  'SNORD67|692108',
#  'SNORD68|606500',
#  'SNORD69|692109',
#  'SNORD6|692075',
#  'SNORD70|692110',
#  'SNORD71|692111',
#  'SNORD72|619564',
#  'SNORD73A|8944',
#  'SNORD74|619498',
#  'SNORD75|692195',
#  'SNORD76|692196',
#  'SNORD77|692197',
#  'SNORD78|692198',
#  'SNORD79|26770',
#  'SNORD7|692076',
#  'SNORD80|26774',
#  'SNORD81|26769',
#  'SNORD82|25826',
#  'SNORD84|692199',
#  'SNORD85|692200',
#  'SNORD86|692201',
#  'SNORD87|641648',
#  'SNORD88A|692202',
#  'SNORD88B|692203',
#  'SNORD88C|692204',
#  'SNORD90|692206',
#  'SNORD91A|692207',
#  'SNORD91B|692208',
#  'SNORD92|692209',
#  'SNORD93|692210',
#  'SNORD95|619570',
#  'SNORD96A|619571',
#  'SNORD96B|692226',
#  'SNORD98|692211',
#  'SNORD99|692212',
#  'SNORD9|692053',
#  'TSSK2|23617',
#  'TTTY17A|252949',
#  'TTTY17B|474151',
#  'TTTY21|252953',
#  'TTTY22|252954',
#  'VTRNA1-1|56664',
#  'VTRNA1-2|56663',
#  'VTRNA1-3|56662',
#  'XKRY|9082']

# %% [markdown]
# We can plot a histogram of the number of unique values in each feature of the dataset.

# %% [markdown]
# Finally, we can access a dataframe with the number of unique values per feature.

# %%
fs.plot_unique()

# %%
fs.unique_stats.sample(5)
# Out:
#                 nunique
# PRG2|5553          1538
# ALAS1|211          1595
# FRMD5|84978        1572
# ANXA5|308          1598
# C6orf134|79969     1596

# %% [markdown]
# # 3. Collinear (highly correlated) Features
#
# This method finds pairs of collinear features based on the Pearson correlation coefficient. For each pair above the specified threshold (in terms of absolute value), it identifies one of the variables to be removed. We need to pass in a `correlation_threshold`.
#
# This method is based on code found at https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
#
# For each pair, the feature that will be removed is the one that comes last in terms of the column ordering in the dataframe. (This method does not one-hot encode the data beforehand unless `one_hot=True`. Therefore correlations are only calculated between numeric columns)

# %%
fs.identify_collinear(correlation_threshold=0.75)
# Out:
# 3495 features with a correlation magnitude greater than 0.75.

# %%
fs.ops['collinear']
# 0.75
# Out:
# ['ACER1|125981',
#  'ACOT2|10965',
#  'ACSL6|23305',
#  'ACTA1|58',
#  'ACTG2|72',
#  'ACTN2|88',
#  'ACTRT2|140625',
#  'ADAM21|8747',
#  'ADH1B|125',
#  'ADRA1A|148',
#  'ADRA1D|146',
#  'AFM|173',
#  'AGER|177',
#  'AIF1|199',
#  'AK7|122481',
#  'AKAP14|158798',
#  'AKAP2|11217',
#  'AKNA|80709',
#  'AKR1B1|231',
#  'AKR1C2|1646',
#  'AKR7L|246181',
#  'ALB|213',
#  'ALDH6A1|4329',
#  'ALOX12B|242',
#  'ALOX12|239',
#  'ALOX5|240',
#  'ALOXE3|59344',
#  'ALS2CR12|130540',
#  'AMICA1|120425',
#  'AMPD1|270',
#  'AMY2A|279',
#  'AMY2B|280',
#  'ANKRD20A4|728747',
#  'ANKRD23|200539',
#  'ANKRD2|26287',
#  'ANKRD58|347454',
#  'ANO1|55107',
#  'ANXA2P2|304',
#  'ANXA2P3|305',
#  'ANXA2|302',
#  'ANXA8|653145',
#  'AOAH|313',
#  'APBB1IP|54518',
#  'APCS|325',
#  'APOA1|335',
#  'APOA2|336',
#  'APOBEC2|10930',
#  'APOBEC4|403314',
#  'APOB|338',
#  'APOC3|345',
#  'APOH|350',
#  'APOM|55937',
#  'AQP12B|653437',
#  'AQP2|359',
#  'AQP4|361',
#  'AQP7P3|441432',
#  'AQPEP|206338',
#  'ARFIP2|23647',
#  'ARG1|383',
#  'ARHGAP10|79658',
#  'ARHGAP11B|89839',
#  'ARHGAP25|9938',
#  'ARHGAP30|257106',
#  'ARHGAP9|64333',
#  'ARHGEF15|22899',
#  'ARHGEF5|7984',
#  'ARL6IP4|51329',
#  'ARMC2|84071',
#  'ARMC3|219681',
#  'ARRB2|409',
#  'ARRDC5|645432',
#  'ART3|419',
#  'ASB10|136371',
#  'ASB15|142685',
#  'ASB18|401036',
#  'ASB5|140458',
#  'ASGR2|433',
#  'ASPM|259266',
#  'ASPRV1|151516',
#  'ATAD5|79915',
#  'ATP1B4|23439',
#  'ATP2C1|27032',
#  'ATP4B|496',
#  'ATP5D|513',
#  'ATP5I|521',
#  'ATP5O|539',
#  'ATP6V0C|527',
#  'AURKAIP1|54998',
#  'AWAT1|158833',
#  'AWAT2|158835',
#  'BAD|572',
#  'BAT3|7917',
#  'BCL11B|64919',
#  'BCL6B|255877',
#  'BCL7C|9274',
#  'BHMT|635',
#  'BIK|638',
#  'BIN2|51411',
#  'BLK|640',
#  'BMPR1B|658',
#  'BMS1P4|729096',
#  'BPIL2|254240',
#  'BPY2|9083',
#  'BRCA2|675',
#  'BRP44|25874',
#  'BTG2|7832',
#  'BTG4|54766',
#  'BTK|695',
#  'BTN3A2|11118',
#  'BTN3A3|10384',
#  'BTNL9|153579',
#  'BUB1B|701',
#  'BUB1|699',
#  'BUD31|8896',
#  'C10orf128|170371',
#  'C10orf129|142827',
#  'C10orf32|119032',
#  'C10orf57|80195',
#  'C10orf67|256815',
#  'C10orf71|118461',
#  'C10orf79|80217',
#  'C10orf93|255352',
#  'C10orf99|387695',
#  'C11orf16|56673',
#  'C11orf21|29125',
#  'C11orf2|738',
#  'C11orf31|280636',
#  'C11orf51|25906',
#  'C11orf52|91894',
#  'C11orf66|220004',
#  'C11orf67|28971',
#  'C11orf75|56935',
#  'C11orf82|220042',
#  'C11orf83|790955',
#  'C11orf88|399949',
#  'C11orf93|120376',
#  'C12orf51|283450',
#  'C12orf57|113246',
#  'C12orf63|374467',
#  'C13orf15|28984',
#  'C13orf26|122046',
#  'C13orf30|144809',
#  'C13orf39|196541',
#  'C14orf115|55237',
#  'C14orf2|9556',
#  'C14orf45|80127',
#  'C14orf49|161176',
#  'C15orf26|161502',
#  'C15orf42|90381',
#  'C16orf13|84326',
#  'C16orf42|115939',
#  'C16orf71|146562',
#  'C17orf106|100134934',
#  'C17orf28|283987',
#  'C17orf61|254863',
#  'C17orf72|92340',
#  'C17orf87|388325',
#  'C17orf89|284184',
#  'C17orf90|339229',
#  'C19orf24|55009',
#  'C19orf43|79002',
#  'C19orf46|163183',
#  'C19orf48|84798',
#  'C19orf51|352909',
#  'C19orf53|28974',
#  'C19orf56|51398',
#  'C19orf59|199675',
#  'C19orf60|55049',
#  'C19orf70|125988',
#  'C1QA|712',
#  'C1QB|713',
#  'C1QC|714',
#  'C1S|716',
#  'C1orf105|92346',
#  'C1orf112|55732',
#  'C1orf115|79762',
#  'C1orf129|80133',
#  'C1orf135|79000',
#  'C1orf141|400757',
#  'C1orf158|93190',
#  'C1orf162|128346',
#  'C1orf172|126695',
#  'C1orf173|127254',
#  'C1orf189|388701',
#  'C1orf192|257177',
#  'C1orf194|127003',
#  'C1orf200|644997',
#  'C1orf68|100129271',
#  'C1orf86|199990',
#  'C1orf87|127795',
#  'C1orf92|149499',
#  'C20orf151|140893',
#  'C20orf160|140706',
#  'C20orf166|128826',
#  'C20orf200|253868',
#  'C20orf27|54976',
#  'C20orf29|55317',
#  'C20orf70|140683',
#  'C20orf85|128602',
#  'C21orf33|8209',
#  'C21orf57|54059',
#  'C22orf15|150248',
#  'C2orf39|92749',
#  'C2orf50|130813',
#  'C2orf62|375307',
#  'C2orf73|129852',
#  'C2orf77|129881',
#  'C2orf79|391356',
#  'C2orf85|285093',
#  'C3AR1|719',
#  'C3orf16|389161',
#  'C3orf36|80111',
#  'C3orf43|255798',
#  'C4orf22|255119',
#  'C4orf40|401137',
#  'C4orf47|441054',
#  'C5AR1|728',
#  'C5orf20|140947',
#  'C5orf49|134121',
#  'C6orf103|79747',
#  'C6orf105|84830',
#  'C6orf118|168090',
#  'C6orf165|154313',
#  'C6orf58|352999',
#  'C6orf97|80129',
#  'C6|729',
#  'C7orf27|221927',
#  'C7orf47|221908',
#  'C7orf57|136288',
#  'C7orf59|389541',
#  'C8orf22|492307',
#  'C8orf58|541565',
#  'C8orf71|26138',
#  'C9orf110|100128385',
#  'C9orf114|51490',
#  'C9orf116|138162',
#  'C9orf117|286207',
#  'C9orf119|375757',
#  'C9orf142|286257',
#  'C9orf152|401546',
#  'C9orf169|375791',
#  'C9orf171|389799',
#  'C9orf23|138716',
#  'C9orf24|84688',
#  'C9orf37|85026',
#  'C9orf71|169693',
#  'C9orf86|55684',
#  'C9orf98|158067',
#  'C9|735',
#  'CA3|761',
#  'CA4|762',
#  'CA6|765',
#  'CAB39L|81617',
#  'CABP1|9478',
#  'CACNA1S|779',
#  'CACNG1|786',
#  'CACNG3|10368',
#  'CACNG6|59285',
#  'CALCRL|10203',
#  'CALD1|800',
#  'CALML3|810',
#  'CALML5|51806',
#  'CANT1|124583',
#  'CAPS2|84698',
#  'CAPSL|133690',
#  'CARD18|59082',
#  'CASC1|55259',
#  'CASC2|255082',
#  'CASC4|113201',
#  'CASC5|57082',
#  'CASP14|23581',
#  'CASP1|834',
#  'CASQ1|844',
#  'CASQ2|845',
#  'CASS4|57091',
#  'CASZ1|54897',
#  'CATSPERB|79820',
#  'CAV1|857',
#  'CAV2|858',
#  'CAV3|859',
#  'CCDC103|388389',
#  'CCDC108|255101',
#  'CCDC113|29070',
#  'CCDC114|93233',
#  'CCDC11|220136',
#  'CCDC124|115098',
#  'CCDC125|202243',
#  'CCDC12|151903',
#  'CCDC135|84229',
#  'CCDC13|152206',
#  'CCDC146|57639',
#  'CCDC147|159686',
#  'CCDC151|115948',
#  'CCDC153|283152',
#  'CCDC157|550631',
#  'CCDC159|126075',
#  'CCDC17|149483',
#  'CCDC19|25790',
#  'CCDC33|80125',
#  'CCDC37|348807',
#  'CCDC39|339829',
#  'CCDC40|55036',
#  'CCDC42B|387885',
#  'CCDC60|160777',
#  'CCDC65|85478',
#  'CCDC72|51372',
#  'CCDC78|124093',
#  'CCDC81|60494',
#  'CCDC85A|114800',
#  'CCDC88B|283234',
#  'CCDC89|220388',
#  'CCDC94|55702',
#  'CCDC96|257236',
#  'CCL19|6363',
#  'CCL4|6351',
#  'CCL5|6352',
#  'CCNA2|890',
#  'CCNB1|891',
#  'CCNB2|9133',
#  'CCNC|892',
#  'CCNL2|81669',
#  'CCNT1|904',
#  'CCR1|1230',
#  'CCR5|1234',
#  'CCR6|1235',
#  'CCR7|1236',
#  'CCS|9973',
#  'CD101|9398',
#  'CD14|929',
#  'CD163|9332',
#  'CD180|4064',
#  'CD19|930',
#  'CD1C|911',
#  'CD1E|913',
#  'CD207|50489',
#  'CD226|10666',
#  'CD22|933',
#  'CD247|919',
#  'CD27|939',
#  'CD28|940',
#  'CD2|914',
#  'CD300A|11314',
#  'CD300C|10871',
#  'CD300LF|146722',
#  'CD300LG|146894',
#  'CD37|951',
#  'CD3D|915',
#  'CD3E|916',
#  'CD3G|917',
#  'CD40LG|959',
#  'CD48|962',
#  'CD4|920',
#  'CD52|1043',
#  'CD53|963',
#  'CD5|921',
#  'CD68|968',
#  'CD6|923',
#  'CD72|971',
#  'CD74|972',
#  'CD79A|973',
#  'CD79B|974',
#  'CD7|924',
#  'CD80|941',
#  'CD84|8832',
#  'CD86|942',
#  'CD8A|925',
#  'CD8B|926',
#  'CD93|22918',
#  'CDC14C|168448',
#  'CDC20|991',
#  'CDC25A|993',
#  'CDC25C|995',
#  'CDC45|8318',
#  'CDC6|990',
#  'CDCA3|83461',
#  'CDCA5|113130',
#  'CDCA8|55143',
#  'CDH5|1003',
#  'CDH9|1007',
#  'CDHR3|222256',
#  'CDHR4|389118',
#  'CDHR5|53841',
#  'CDK1|983',
#  'CDK3|1018',
#  'CDK5|1020',
#  'CDKN3|1033',
#  'CDO1|1036',
#  'CDSN|1041',
#  'CDT1|81620',
#  'CDX4|1046',
#  'CEACAM18|729767',
#  'CECR1|51816',
#  'CECR6|27439',
#  'CELA3A|10136',
#  'CELA3B|23436',
#  'CEL|1056',
#  'CENPA|1058',
#  'CENPE|1062',
#  'CENPF|1063',
#  'CENPI|2491',
#  'CENPK|64105',
#  'CENPL|91687',
#  'CENPO|79172',
#  'CEP152|22995',
#  'CEP55|55165',
#  'CES4|51716',
#  'CFHR2|3080',
#  'CFP|5199',
#  'CGB5|93659',
#  'CGB7|94027',
#  'CGB|1082',
#  'CHCHD1|118487',
#  'CHCHD5|84269',
#  'CHCHD8|51287',
#  'CHD6|84181',
#  'CHDH|55349',
#  'CHKB-CPT1B|386593',
#  'CHMP2A|27243',
#  'CHRM1|1128',
#  'CHRNA7|1139',
#  'CHRND|1144',
#  'CHST4|10164',
#  'CIDEA|1149',
#  'CIITA|4261',
#  'CIRBP|1153',
#  'CISD3|284106',
#  'CKAP2L|150468',
#  'CKAP2|26586',
#  'CKM|1158',
#  'CLCN7|1186',
#  'CLCNKA|1187',
#  'CLDN18|51208',
#  'CLDN19|149461',
#  'CLDN20|49861',
#  'CLDN3|1365',
#  'CLEC14A|161198',
#  'CLEC17A|388512',
#  'CLEC18B|497190',
#  'CLEC3B|7123',
#  'CLEC4A|50856',
#  'CLEC4GP1|440508',
#  'CLEC4M|10332',
#  'CLEC6A|93978',
#  'CLEC7A|64581',
#  'CLECL1|160365',
#  'CLIC5|53405',
#  'CLK4|57396',
#  'CLN6|54982',
#  'CLNS1A|1207',
#  'CLPP|8192',
#  'CLPS|1208',
#  'CLRN3|119467',
#  'CLSPN|63967',
#  'CMYA5|202333',
#  'CNFN|84518',
#  'CNGA4|1262',
#  'CNKSR1|10256',
#  'CNN1|1264',
#  'CNR2|1269',
#  'CNTLN|54875',
#  'COBRA1|25920',
#  'COG3|83548',
#  'COL10A1|1300',
#  'COL1A2|1278',
#  'COL3A1|1281',
#  'COL4A2|1284',
#  'COL4A4|1286',
#  'COL5A1|1289',
#  'COL5A2|1290',
#  'COL6A2|1292',
#  'COL6A3|1293',
#  'COL6A6|131873',
#  'COL8A2|1296',
#  'COMMD4|54939',
#  'COPE|11316',
#  'COQ4|51117',
#  'COQ7|10229',
#  'CORO1A|11151',
#  'CORO1B|57175',
#  'CORO2A|7464',
#  'CORO6|84940',
#  'COX4I1|1327',
#  'COX4I2|84701',
#  'COX5B|1329',
#  'COX6A1|1337',
#  'COX6A2|1339',
#  'COX6B1|1340',
#  'CPA1|1357',
#  'CPLX2|10814',
#  'CPNE4|131034',
#  'CPSF3L|54973',
#  'CPSF4|10898',
#  'CR1|1378',
#  'CR2|1380',
#  'CRB2|286204',
#  'CRB3|92359',
#  'CRCT1|54544',
#  'CREB3L3|84699',
#  'CREB3L4|148327',
#  'CRH|1392',
#  'CRISP1|167',
#  'CRTAM|56253',
#  'CSAG2|728461',
#  'CSAG3|389903',
#  'CSF1R|1436',
#  'CSF2RB|1439',
#  'CSH1|1442',
#  'CSH2|1443',
#  'CSNK1G2|1455',
#  'CSNK2A1|1457',
#  'CSNK2B|1460',
#  'CSRNP1|64651',
#  'CSRP1|1465',
#  'CSRP3|8048',
#  'CST6|1474',
#  'CSTA|1475',
#  'CT45A3|441519',
#  'CT45A5|441521',
#  'CT47A7|653282',
#  'CTAGE6|340307',
#  'CTAGE9|643854',
#  'CTRB2|440387',
#  'CTRC|11330',
#  'CTSS|1520',
#  'CTSW|1521',
#  'CUEDC2|79004',
#  'CUL4A|8451',
#  'CUTA|51596',
#  'CUX2|23316',
#  'CXCL13|10563',
#  'CXCL3|2921',
#  'CXCL9|4283',
#  'CXCR2P1|3580',
#  'CXCR2|3579',
#  'CXCR3|2833',
#  'CXCR5|643',
#  'CXCR6|10663',
#  'CXorf21|80231',
#  'CXorf22|170063',
#  'CXorf27|25763',
#  'CXorf30|645090',
#  'CXorf36|79742',
#  'CXorf40B|541578',
#  'CXorf41|139212',
#  'CXorf59|286464',
#  'CYB561|1534',
#  'CYBB|1536',
#  'CYHR1|50626',
#  'CYMP|643160',
#  'CYP11B1|1584',
#  'CYP11B2|1585',
#  'CYP17A1|1586',
#  'CYP21A2|1589',
#  'CYP2A7|1549',
#  'CYP2C9|1559',
#  'CYP2F1|1572',
#  'CYP3A4|1576',
#  'CYP4A11|1579',
#  'CYP4F22|126410',
#  'CYP4F8|11283',
#  'CYP8B1|1582',
#  'CYTH4|27128',
#  'CYTIP|9595',
#  'CYYR1|116159',
#  'D2HGDH|728294',
#  'DAD1L|56286',
#  'DAPK2|23604',
#  'DAPL1|92196',
#  'DARC|2532',
#  'DAZ2|57055',
#  'DAZ3|57054',
#  'DBH|1621',
#  'DBT|1629',
#  'DCAF6|55827',
#  'DCDC1|341019',
#  'DCDC2B|149069',
#  'DCI|1632',
#  'DCLK3|85443',
#  'DCUN1D2|55208',
#  'DCXR|51181',
#  'DDN|23109',
#  'DDT|1652',
#  'DDX49|54555',
#  'DEFA5|1670',
#  'DEFA6|1671',
#  'DEFB103B|414325',
#  'DEFB110|245913',
#  'DEFB112|245915',
#  'DEFB125|245938',
#  'DEFB126|81623',
#  'DEFB127|140850',
#  'DEFB129|140881',
#  'DEFB131|644414',
#  'DEFB132|400830',
#  'DEFB4A|1673',
#  'DENND1C|79958',
#  'DENND3|22898',
#  'DERL3|91319',
#  'DES|1674',
#  'DGAT2L6|347516',
#  'DGAT2|84649',
#  'DGCR9|25787',
#  'DGKK|139189',
#  'DHPS|1725',
#  'DHRS4|10901',
#  'DHRS7C|201140',
#  'DHRS7|51635',
#  'DHX16|8449',
#  'DHX30|22907',
#  'DHX38|9785',
#  'DIAPH3|81624',
#  'DIRAS2|54769',
#  'DIXDC1|85458',
#  'DKK4|27121',
#  'DLEC1|9940',
#  'DLGAP5|9787',
#  'DLX2|1746',
#  'DMAP1|55929',
#  'DMGDH|29958',
#  'DMKN|93099',
#  'DMPK|1760',
#  'DNAH10|196385',
#  'DNAH12|201625',
#  'DNAH3|55567',
#  'DNAH6|1768',
#  'DNAH7|56171',
#  'DNAH9|1770',
#  'DNAI1|27019',
#  'DNAI2|64446',
#  'DNAJB2|3300',
#  'DNAJB5|25822',
#  'DNAJC17|55192',
#  'DNAJC4|3338',
#  'DNAJC5B|85479',
#  'DNAJC9|23234',
#  'DNMT1|1786',
#  'DOCK2|1794',
#  'DOCK8|81704',
#  'DOHH|83475',
#  'DOK2|9046',
#  'DOK3|79930',
#  'DOPEY2|9980',
#  'DPCR1|135656',
#  'DPEP2|64174',
#  'DPF1|8193',
#  'DRG2|1819',
#  'DSC1|1823',
#  'DSC3|1825',
#  'DSCR8|84677',
#  'DSG1|1828',
#  'DSG3|1830',
#  'DTHD1|401124',
#  'DTL|51514',
#  'DUOXA1|90527',
#  'DUOXA2|405753',
#  'DUPD1|338599',
#  'DUS1L|64118',
#  'DUSP26|78986',
#  'DUSP27|92235',
#  'DYDC1|143241',
#  'DYDC2|84332',
#  'DYNC2H1|79659',
#  'DYNLRB1|83658',
#  'DYNLRB2|83657',
#  'DYRK2|8445',
#  'DYSFIP1|116729',
#  'E2F1|1869',
#  'E2F2|1870',
#  'E4F1|1877',
#  'EBF2|64641',
#  'EBI3|10148',
#  'ECHDC2|55268',
#  'ECHS1|1892',
#  'ECM2|1842',
#  'ECSCR|641700',
#  'ECSIT|51295',
#  'EDC4|23644',
#  'EDDM3A|10876',
#  'EDDM3B|64184',
#  'EDF1|8721',
#  'EEF1A1|1915',
#  'EEF1D|1936',
#  'EFCAB10|100130771',
#  'EFCAB1|79645',
#  'EFCAB3|146779',
#  'EFCAB6|64800',
#  'EFHB|151651',
#  'EFTUD2|9343',
#  'EGR1|1958',
#  'EHF|26298',
#  'EHMT2|10919',
#  'EIF2B4|8890',
#  'EIF3G|8666',
#  'EIF3H|8667',
#  'EIF3L|51386',
#  'EIF5AL1|143244',
#  'EIF5A|1984',
#  'ELANE|1991',
#  'ELMO3|79767',
#  'ELOF1|84337',
#  'ELOVL3|83401',
#  'ELOVL7|79993',
#  'EME1|146956',
#  'EMP2|2013',
#  'EMR3|84658',
#  'EMX2OS|196047',
#  'EMX2|2018',
#  'ENDOG|2021',
#  'ENDOU|8909',
#  'ENKUR|219670',
#  'ENTPD5|957',
#  'EPAS1|2034',
#  'EPB42|2038',
#  'EPHX2|2053',
#  'EPN1|29924',
#  'EPN3|55040',
#  'EPR1|8475',
#  'EPS8L3|79574',
#  'EPYC|1833',
#  'ERCC6L|54821',
#  'ERF|2077',
#  'ERGIC1|57222',
#  'ESAM|90952',
#  'ESCO2|157570',
#  'ESPL1|9700',
#  'ETFA|2108',
#  'EVI2A|2123',
#  'EVI2B|2124',
#  'EXD3|54932',
#  'EXO1|9156',
#  'EXOSC4|54512',
#  'EZH2|2146',
#  'F13B|2165',
#  'F2|2147',
#  'F9|2158',
#  'FAAH|2166',
#  'FABP12|646486',
#  'FABP1|2168',
#  'FABP4|2167',
#  'FABP9|646480',
#  'FAIM3|9214',
#  'FAM106A|80039',
#  'FAM106C|100129396',
#  'FAM108A1|81926',
#  'FAM108B1|51104',
#  'FAM120A|23196',
#  'FAM123C|205147',
#  'FAM125A|93343',
#  'FAM127B|26071',
#  'FAM128A|653784',
#  'FAM128B|80097',
#  'FAM129C|199786',
#  'FAM13C|220965',
#  'FAM151A|338094',
#  'FAM154B|283726',
#  'FAM158A|51016',
#  'FAM159A|348378',
#  'FAM162B|221303',
#  'FAM174B|400451',
#  'FAM179A|165186',
#  'FAM183A|440585',
#  'FAM186A|121006',
#  'FAM195A|84331',
#  'FAM195B|348262',
#  'FAM22F|54754',
#  'FAM25A|643161',
#  'FAM25B|100132929',
#  'FAM26D|221301',
#  'FAM26F|441168',
#  'FAM27C|100132948',
#  'FAM35B2|439965',
#  'FAM35B|414241',
#  'FAM43B|163933',
#  'FAM45B|55855',
#  'FAM54A|113115',
#  'FAM55D|54827',
#  'FAM57B|83723',
#  'FAM63B|54629',
#  'FAM64A|54478',
#  'FAM72B|653820',
#  'FAM72D|728833',
#  'FAM74A1|401507',
#  'FAM75A3|727830',
#  'FAM75A5|727905',
#  'FAM7A3|89837',
#  'FAM81B|153643',
#  'FAM83C|128876',
#  'FAM83G|644815',
#  'FAM86B2|653333',
#  'FAM92B|339145',
#  'FAM98C|147965',
#  'FAM99A|387742',
#  'FAM9A|171482',
#  'FANCD2|2177',
#  'FANCI|55215',
#  'FANCM|57697',
#  'FANK1|92565',
#  'FARSA|2193',
#  'FASLG|356',
#  'FBL|2091',
#  'FBN1|2200',
#  'FBN2|2201',
#  'FBP2|8789',
#  'FBXL15|79176',
#  'FBXL22|283807',
#  'FBXL6|26233',
#  'FBXL8|55336',
#  'FBXO15|201456',
#  'FBXO22OS|692224',
#  'FBXO22|26263',
#  'FBXO25|26260',
#  'FBXO39|162517',
#  'FBXO40|51725',
#  'FBXO5|26271',
#  'FBXW4|6468',
#  'FCAMR|83953',
#  'FCER1A|2205',
#  'FCER2|2208',
#  'FCGR1A|2209',
#  'FCGR1B|2210',
#  'FCGR1C|100132417',
#  'FCGR3A|2214',
#  'FCGR3B|2215',
#  'FCN3|8547',
#  'FCRL1|115350',
#  'FCRL2|79368',
#  'FCRL3|115352',
#  'FCRL5|83416',
#  'FDX1L|112812',
#  'FEN1|2237',
#  'FER1L6|654463',
#  'FERD3L|222894',
#  'FERMT3|83706',
#  'FETUB|26998',
#  'FGB|2244',
#  'FGD2|221472',
#  'FGD3|89846',
#  'FGD5|152273',
#  'FGF20|26281',
#  'FGF3|2248',
#  'FGF6|2251',
#  'FGFBP1|9982',
#  'FGFR1OP|11116',
#  'FGG|2266',
#  'FGR|2268',
#  'FHAD1|114827',
#  'FHL1|2273',
#  'FHL5|9457',
#  'FIBP|9158',
#  'FIGF|2277',
#  'FIS1|51024',
#  'FITM1|161247',
#  'FKBP2|2286',
#  'FKBP8|23770',
#  'FKBPL|63943',
#  'FLG2|388698',
#  'FLG|2312',
#  'FLI1|2313',
#  'FLJ40330|645784',
#  'FLJ43390|646113',
#  'FLJ43860|389690',
#  'FLJ43950|347127',
#  'FLJ45983|399717',
#  'FLNB|2317',
#  'FLNC|2318',
#  'FLT3|2322',
#  'FLYWCH1|84256',
#  'FLYWCH2|114984',
#  'FMNL1|752',
#  'FMO2|2327',
#  'FNDC1|84624',
#  'FOLH1|2346',
#  'FOLR1|2348',
#  'FOLR2|2350',
#  'FOSB|2354',
#  'FOS|2353',
#  'FOXA1|3169',
#  'FOXD4|2298',
#  'FOXF1|2294',
#  'FOXJ1|2302',
#  'FOXL2|668',
#  'FOXM1|2305',
#  'FOXN1|8456',
#  'FOXO3|2309',
#  'FOXP3|50943',
#  'FPR1|2357',
#  'FPR2|2358',
#  'FPR3|2359',
#  'FRG2B|441581',
#  'FRG2C|100288801',
#  'FRMPD2|143162',
#  'FRS2|10818',
#  'FSD2|123722',
#  'FSHB|2488',
#  'FTHL3|2498',
#  'FUT7|2529',
#  'FYB|2533',
#  'FZR1|51343',
#  'G6PC|2538',
#  'GAB3|139716',
#  'GABARAP|11337',
#  'GABRA6|2559',
#  'GABRP|2568',
#  'GABRR3|200959',
#  'GADD45GIP1|90480',
#  'GAGE12J|729396',
#  'GAGE2D|729408',
#  'GAGE8|100101629',
#  'GALNT7|51809',
#  'GALP|85569',
#  'GAMT|2593',
#  'GAPT|202309',
#  'GAS2L2|246176',
#  'GAS5|60674',
#  'GATA1|2623',
#  'GATA2|2624',
#  'GATAD2A|54815',
#  'GBAP1|2630',
#  'GBA|2629',
#  'GBP1|2633',
#  'GBP2|2634',
#  'GBP5|115362',
#  'GCAT|23464',
#  'GCC2|9648',
#  'GCDH|2639',
#  'GCET2|257144',
#  'GCOM1|145781',
#  'GDF10|2662',
#  'GDF6|392255',
#  'GDPD5|81544',
#  'GEFT|115557',
#  'GFER|2671',
#  'GFI1B|8328',
#  'GFPT1|2673',
#  'GFRA4|64096',
#  'GGTA1|2681',
#  'GGTLC2|91227',
#  'GIF|2694',
#  'GIMAP1|170575',
#  'GIMAP2|26157',
#  'GIMAP4|55303',
#  'GIMAP5|55340',
#  'GIMAP6|474344',
#  'GIMAP7|168537',
#  'GIMAP8|155038',
#  'GINS1|9837',
#  'GJA5|2702',
#  'GJB2|2706',
#  'GK5|256356',
#  'GK|2710',
#  'GLB1L2|89944',
#  'GLB1L3|112937',
#  'GLDN|342035',
#  'GLI4|2738',
#  'GLRA4|441509',
#  'GLTPD1|80772',
#  'GLTSCR2|29997',
#  'GLUD1|2746',
#  'GLYAT|10249',
#  'GMFG|9535',
#  'GMIP|51291',
#  'GNB2L1|10399',
#  'GNGT2|2793',
#  'GNRH2|2797',
#  'GOLGA6B|55889',
#  'GOLGA6L5|374650',
#  'GOLGA6L6|727832',
#  'GOLGA6L9|440295',
#  'GOLGA8B|440270',
#  'GOLGA8C|729786',
#  'GOLGA8DP|100132979',
#  'GOLGB1|2804',
#  'GOLM1|51280',
#  'GOT1L1|137362',
#  'GP1BA|2811',
#  'GPAA1|8733',
#  'GPD1|2819',
#  'GPIHBP1|338328',
#  'GPR114|221188',
#  'GPR142|350383',
#  'GPR143|4935',
#  'GPR144|347088',
#  'GPR146|115330',
#  'GPR149|344758',
#  'GPR162|27239',
#  'GPR174|84636',
#  'GPR18|2841',
#  'GPR4|2828',
#  'GPR65|8477',
#  'GPRASP1|9737',
#  'GPS1|2873',
#  'GPS2|2874',
#  'GRAP|10750',
#  'GRB7|2886',
#  'GRHL2|79977',
#  'GRHL3|57822',
#  'GRIN3B|116444',
#  'GRINA|2907',
#  'GRK5|2869',
#  'GRM4|2914',
#  ...]

# %% [markdown]
# We can view a heatmap of the correlations above the threhold. The features which will be dropped are on the x-axis.

# %%
# fs.plot_collinear()

# %% [markdown]
# To plot all of the correlations in the data, we can pass in `plot_all = True` to the `plot_collinear` function.

# %%
fs.record_collinear
# Out:
#        drop_feature   corr_feature  corr_value
# 0      ACER1|125981    ABCG4|64137    0.793207
# 1       ACOT2|10965   ACOT1|641371    0.867820
# 2       ACSL6|23305     ABCG2|9429    0.813657
# 3          ACTA1|58    ABRA|137735    0.775379
# 4          ACTG2|72       ACTA2|59    0.951598
# ...             ...            ...         ...
# 52695   ZWINT|11130  RACGAP1|29127    0.772828
# 52696   ZWINT|11130      RRM2|6241    0.773268
# 52697   ZWINT|11130   SGOL1|151648    0.756932
# 52698   ZWINT|11130    SPAG5|10615    0.786478
# 52699   ZWINT|11130     TPX2|22974    0.763583
#
# [52700 rows x 3 columns]

# %%
fs.remove(methods = ['collinear'])
# Out:
# Removed 3495 features.
#       ?|100130426  ?|100133144  ?|100134869   ?|10357   ?|10431  ?|136542  \
# 0             0.0       4.4709       6.4338  143.5700  1224.560       0.0
# 1             0.0       5.2474       8.0016   84.6612   560.474       0.0
# 2             0.0       5.3404       3.8794  118.8790   629.787       0.0
# 3             0.0       0.3247       0.0000   92.8766   544.805       0.0
# 4             0.0       3.1889       3.3861  163.9870   771.070       0.0
# ...           ...          ...          ...       ...       ...       ...
# 1595          0.0      15.5193      22.9872  100.1870   873.979       0.0
# 1596          0.0       8.4195      10.3226   74.7210   766.745       0.0
# 1597          0.0      42.9857      81.1128   85.3715   677.733       0.0
# 1598          0.0      14.0861      24.1914   61.1388  1137.320       0.0
# 1599          0.0      20.5338       8.9500   76.9265   565.433       0.0
#
#       ?|155060  ?|26823  ?|280660  ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# 0     110.6620   0.8078    0.0000       0.0  ...    16.5590      164.782
# 1     631.1350   0.4015    0.0000       0.0  ...    46.1708      286.259
# 2     216.3120   0.0000    0.0000       0.0  ...    25.5319      234.752
# 3      72.0779   0.0000    0.6494       0.0  ...    33.4416      245.130
# 4     275.2540   0.0000    0.0000       0.0  ...    49.6115      300.060
# ...        ...      ...       ...       ...  ...        ...          ...
# 1595  256.1260   1.1669    0.0000       0.0  ...    40.8401      329.055
# 1596  370.2770   0.7209    0.0000       0.0  ...    50.6998      374.362
# 1597  334.7450   0.0000    0.0000       0.0  ...    16.9433      168.975
# 1598  170.8130   2.8708    0.0000       0.0  ...   136.3640      562.679
# 1599  377.3920   0.6552    0.0000       0.0  ...    60.2780      364.289
#
#       ZXDC|79364  ZYG11A|440590  ZYG11B|79699  ZYX|7791  ZZEF1|23140  \
# 0        773.425         7.2698       644.588   1236.27      622.779
# 1       1020.580         0.8030       690.154   3594.50      883.670
# 2       1126.240        15.6028       849.645   3270.21     1105.670
# 3       1023.700         0.0000       436.039   5132.14     1796.100
# 4        742.977         0.0000       991.632   5128.21     1097.430
# ...          ...            ...           ...       ...          ...
# 1595    1107.350        17.5029       726.371   4185.53     1333.720
# 1596    1485.430        52.6221       757.854   3077.79     1989.310
# 1597    1224.960        10.0744       531.654   1995.19     1424.160
# 1598    1296.650         0.4785       782.297   4483.25     1520.570
# 1599    1830.620         6.5520       623.091   5346.39     1582.950
#
#       ZZZ3|26009  psiTPTE22|387590  tAKR|389932
# 0        721.325            2.8271       0.0000
# 1       1137.810            4.8178       0.4015
# 2        769.504          197.1630       0.0000
# 3        286.039            2.5974       0.0000
# 4       1659.000            1.7932       0.0000
# ...          ...               ...          ...
# 1595     585.181          536.1730       0.0000
# 1596     611.762          757.3740       1.2014
# 1597     426.789            5.4951       0.0000
# 1598     477.990          186.1240       0.4785
# 1599     509.742          318.4250       0.0000
#
# [1600 rows x 17036 columns]

# %% [markdown]
# ## collinear threshold를 넘은 feature들을 제거하여 따로 data, labels로 저장

# %%
import torch
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
lb.fit(y_)
y=lb.transform(y_)

# %% [markdown]
# # 4. Zero Importance Features
#
# This method relies on a machine learning model to identify features to remove. It therefore requires a supervised learning problem with labels. The method works by finding feature importances using a gradient boosting machine implemented in the [LightGBM library](http://lightgbm.readthedocs.io/en/latest/Quick-Start.html).
#
# To reduce variance in the calculated feature importances, the model is trained a default 10 times. The model is also by default trained with early stopping using a validation set (15% of the training data) to identify the optimal number of estimators to train. The following parameters can be passed to the `identify_zero_importance` method:
#
# * `task`: either `classification` or `regression`. The metric and labels must match with the task
# * `eval_metric`: the metric used for early stopping (for example `auc` for classification or `l2` for regression). To see a list of available metrics, refer to the [LightGBM docs](http://testlightgbm.readthedocs.io/en/latest/Parameters.html#metric-parameters)
# * `n_iterations`: number of training runs. The feature importances are averaged over the training runs (default = 10)
# * `early_stopping`: whether to use early stopping when training the model (default = True). [Early stopping](https://en.wikipedia.org/wiki/Early_stopping) stops training estimators (decision trees) when the performance on a validation set no longer decreases for a specified number of estimators (100 by default in this implementation). Early stopping is a form of regularization used to prevent overfitting to training data
#
# The data is first one-hot encoded for use in the model. This means that some of the zero importance features may be created from one-hot encoding. To view the one-hot encoded columns, we can access the `one_hot_features` of the `FeatureSelector`.
#
# __Note of caution__: in contrast to the other methods, the feature imporances from a model are non-deterministic (have a little randomness). The results of running this method can change each time it is run.

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2]	valid_0's auc: 0.0200091
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.00596497
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.00634249
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.00358653
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.00826789
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2]	valid_0's auc: 0.0175551
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.0156675
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.0178949
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [6]	valid_0's auc: 0.0251435
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.0222742
#
# 20166 features with zero importance after one-hot encoding.

# %% [markdown]
# Running the gradient boosting model requires one hot encoding the features. These features are saved in the `one_hot_features` attribute of the `FeatureSelector`. The original features are saved in the `base_features`.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 20531 original features
# There are 0 one-hot features

# %% [markdown]
# The `data` attribute of the `FeatureSelector` holds the original dataframe. After one-hot encoding, the `data_all` attribute holds the original data plus the one-hot encoded features.

# %%
fs.data_all.head(10)
# Out:
#    ?|100130426  ?|100133144  ?|100134869   ?|10357   ?|10431  ?|136542  \
# 0          0.0       4.4709       6.4338  143.5700  1224.560       0.0
# 1          0.0       5.2474       8.0016   84.6612   560.474       0.0
# 2          0.0       5.3404       3.8794  118.8790   629.787       0.0
# 3          0.0       0.3247       0.0000   92.8766   544.805       0.0
# 4          0.0       3.1889       3.3861  163.9870   771.070       0.0
# 5          0.0       0.5353       1.2026  121.2030   793.535       0.0
# 6          0.0       1.3536       3.8408  161.8640   988.771       0.0
# 7          0.0      22.9168      15.8059  133.9100   988.485       0.0
# 8          0.0       2.5883       5.6833  180.9170   481.820       0.0
# 9          0.0       0.6567       1.7937   60.3480   626.317       0.0
#
#    ?|155060  ?|26823  ?|280660  ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# 0  110.6620   0.8078    0.0000       0.0  ...    16.5590      164.782
# 1  631.1350   0.4015    0.0000       0.0  ...    46.1708      286.259
# 2  216.3120   0.0000    0.0000       0.0  ...    25.5319      234.752
# 3   72.0779   0.0000    0.6494       0.0  ...    33.4416      245.130
# 4  275.2540   0.0000    0.0000       0.0  ...    49.6115      300.060
# 5   39.6246   0.0000    0.0000       0.0  ...    33.3681      205.075
# 6   65.0829   0.0000    0.0000       0.0  ...    40.9442      218.471
# 7   76.7414   0.0000   13.3769       0.0  ...    18.6573      123.209
# 8  384.2840   0.3446    0.3446       0.0  ...    39.6347      242.978
# 9   77.9221   0.0000    0.0000       0.0  ...    23.0336      137.221
#
#    ZXDC|79364  ZYG11A|440590  ZYG11B|79699  ZYX|7791  ZZEF1|23140  ZZZ3|26009  \
# 0     773.425         7.2698       644.588   1236.27      622.779     721.325
# 1    1020.580         0.8030       690.154   3594.50      883.670    1137.810
# 2    1126.240        15.6028       849.645   3270.21     1105.670     769.504
# 3    1023.700         0.0000       436.039   5132.14     1796.100     286.039
# 4     742.977         0.0000       991.632   5128.21     1097.430    1659.000
# 5     765.033         5.5613       500.521   4675.70     1398.330     521.029
# 6     875.716         1.2222       737.606   3177.76     1648.770     651.440
# 7     814.585         9.5047      1013.480  10974.00     1287.710     858.236
# 8     998.794         1.7232       945.718   3042.22     1335.520     962.261
# 9     748.346         0.0000       180.838   7198.73     1472.680     300.907
#
#    psiTPTE22|387590  tAKR|389932
# 0            2.8271       0.0000
# 1            4.8178       0.4015
# 2          197.1630       0.0000
# 3            2.5974       0.0000
# 4            1.7932       0.0000
# 5          328.4670       0.0000
# 6            0.9167       0.0000
# 7            5.6324       0.0000
# 8            4.8251       0.3446
# 9            7.3511       0.0000
#
# [10 rows x 20531 columns]

# %% [markdown]
# There are a number of methods we can use to inspect the results of the feature importances. First we can access the list of features with zero importance.

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features
# Out:
# ['PLLP|51090',
#  'POM121L4P|266697',
#  'PLEKHG7|440107',
#  'POM121C|100101267',
#  'PLEKHG6|55200',
#  'PLN|5350',
#  'POLR2A|5430',
#  'PLOD1|5351',
#  'POM121L10P|646074',
#  'PLEKHG4|25894',
#  'PLP2|5355',
#  'PLP1|5354',
#  'POLR2D|5433',
#  'POM121L1P|25812',
#  'POLR1E|64425',
#  'POM121L12|285877',
#  'POLR2C|5432',
#  'PLOD2|5352',
#  'PLK5P|126520',
#  'POLR2B|5431',
#  'PLEKHG5|57449',
#  'PLOD3|8985',
#  'POM121L2|94026',
#  'POLRMT|5442',
#  'PLK4|10733',
#  'PLEKHN1|84069',
#  'PLIN3|10226',
#  'POLR2J|5439',
#  'PLIN2|123',
#  'POLR2K|5440',
#  'PLEKHM3|389072',
#  'POLR2L|5441',
#  'PLS1|5357',
#  'POLR3GL|84265',
#  'POLR3F|10621',
#  'POLR3A|11128',
#  'POLR2F|5435',
#  'PLIN1|5346',
#  'PLEKHO1|51177',
#  'PLG|5340',
#  'PLEKHO2|80301',
#  'PLGLB2|5342',
#  'POLR3B|55703',
#  'PLGLA|285189',
#  'PLEK|5341',
#  'POLR3C|10623',
#  'PLIN4|729359',
#  'PLEKHM2|23207',
#  'PLEKHM1|9842',
#  'POLR3G|10622',
#  'POLR2G|5436',
#  'POLR2H|5437',
#  'PLK3|1263',
#  'PLK2|10769',
#  'PLK1|5347',
#  'PLK1S1|55857',
#  'POLR3D|661',
#  'PLEKHH1|57475',
#  'POLR2I|5438',
#  'PLEKHH2|130271',
#  'POLR3K|51728',
#  'POLR3H|171568',
#  'POLR2J2|246721',
#  'PLEKHH3|79990',
#  'PLIN5|440503',
#  'PLEKHJ1|55111',
#  'POLR2J3|548644',
#  'POLR2J4|84820',
#  'PLEKHM1P|440456',
#  'PLRG1|5356',
#  'PMS2L2|5380',
#  'PLS3|5358',
#  'PNOC|5368',
#  'PMFBP1|83449',
#  'PNMA6A|84968',
#  'PMF1|11243',
#  'PMEPA1|56937',
#  'PNMAL1|55228',
#  'PMCH|5367',
#  'PNMAL2|57469',
#  'PNMT|5409',
#  'PNN|5411',
#  'PMCHL2|5370',
#  'PNO1|56902',
#  'PMCHL1|5369',
#  'PNPLA1|285848',
#  'PLSCR1|5359',
#  'PNPLA2|57104',
#  'PNPLA3|80339',
#  'PNPLA4|8228',
#  'PNPLA5|150379',
#  'PNPLA6|10908',
#  'PNPLA7|375775',
#  'PMAIP1|5366',
#  'PNPLA8|50640',
#  'PNPO|55163',
#  'PM20D2|135293',
#  'PNPT1|87178',
#  'PNP|4860',
#  'PNMA5|114824',
#  'PML|5371',
#  'PNMA3|29944',
#  'PNMA2|10687',
#  'PMS2L3|5387',
#  'PMS2L4|5382',
#  'PMS2L5|5383',
#  'PMS2|5395',
#  'PMS2L1|5379',
#  'PMVK|10654',
#  'PNCK|139728',
#  'PMS2L11|441263',
#  'PMS2CL|441194',
#  'PMS1|5378',
#  'PMPCB|9512',
#  'PMPCA|23203',
#  'PNKD|25953',
#  'PMP2|5375',
#  'PNKP|11284',
#  'PMP22|5376',
#  'PNLDC1|154197',
#  'POM121L8P|29797',
#  'PNLIPRP1|5407',
#  'PNLIPRP2|5408',
#  'PMM2|5373',
#  'PNLIPRP3|119548',
#  'PNLIP|5406',
#  'PNMA1|9240',
#  'PMM1|5372',
#  'PNRC1|10957',
#  'PM20D1|148811',
#  'PNRC2|55629',
#  'POLD2|5425',
#  'PLUNC|51297',
#  'POLD4|57804',
#  'PLTP|5360',
#  'POLDIP2|26073',
#  'POLE2|5427',
#  'PLSCR5|389158',
#  'POLE3|54107',
#  'POLE4|56655',
#  'POLE|5426',
#  'POLG2|11232',
#  'POLG|5428',
#  'POLH|5429',
#  'POLI|11201',
#  'POLK|51426',
#  'POLL|27343',
#  'POLM|27434',
#  'POLN|353497',
#  'POLQ|10721',
#  'PLSCR4|57088',
#  'PLSCR3|57048',
#  'POLR1A|25885',
#  'PLSCR2|57047',
#  'POLR1B|84172',
#  'POLR1C|9533',
#  'POLR1D|51082',
#  'POLD3|10714',
#  'PLVAP|83483',
#  'POC1A|25886',
#  'PLXDC1|57125',
#  'POC1B|282809',
#  'POC5|134359',
#  'PODNL1|79883',
#  'PLXND1|23129',
#  'PODN|127435',
#  'PLXNC1|10154',
#  'PLXNB3|5365',
#  'PODXL2|50512',
#  'PODXL|5420',
#  'POF1B|79983',
#  'PLXNB2|23654',
#  'POFUT1|23509',
#  'POFUT2|23275',
#  'POGK|57645',
#  'PLXNB1|5364',
#  'POGZ|23126',
#  'POLA1|5422',
#  'POLA2|23649',
#  'PLXNA4|91584',
#  'PLXNA3|55558',
#  'POLB|5423',
#  'POLD1|5424',
#  'PLXNA2|5362',
#  'PLXNA1|5361',
#  'PLXDC2|84898',
#  'POLDIP3|84271',
#  '?|100130426',
#  'POM121L9P|29774',
#  'PRAMEF2|65122',
#  'PRAMEF20|645425',
#  'PRAMEF1|65121',
#  'PRAMEF18|391003',
#  'PRAMEF17|391004',
#  'PRAMEF16|654348',
#  'PRAMEF14|729528',
#  'PRAMEF13|400736',
#  'PRAMEF12|390999',
#  'PRAMEF11|440560',
#  'PRAMEF10|343071',
#  'PRAM1|84106',
#  'PRAF2|11230',
#  'PRAC|84366',
#  'PQLC3|130814',
#  'PQLC2|54896',
#  'PRAMEF22|653606',
#  'PRAMEF3|401940',
#  'PPP2CB|5516',
#  'PRAMEF4|400735',
#  'PRDM10|56980',
#  'PRCP|5547',
#  'PRCD|768206',
#  'PRCC|5546',
#  'PRC1|9055',
#  'PRB4|5545',
#  'PRB3|5544',
#  'PRB2|653247',
#  'PRB1|5542',
#  'PRAP1|118471',
#  'PRAME|23532',
#  'PRAMEF9|343070',
#  'PRAMEF8|391002',
#  'PRAMEF6|440561',
#  'PRAMEF5|343068',
#  'PQLC1|80148',
#  'PQBP1|10084',
#  'PPY|5539',
#  'PPYR1|5540',
#  'PPP3CA|5530',
#  'PPP2R5E|5529',
#  'PPP2R5D|5528',
#  'PPP2R5C|5527',
#  'PPP2R5B|5526',
#  'PPP2R5A|5525',
#  'PPP2R4|5524',
#  'PPP2R3C|55012',
#  'PPP2R3B|28227',
#  'PPP2R3A|5523',
#  'PPP2R2D|55844',
#  'PPP2R2C|5522',
#  'PPP2R2B|5521',
#  'PPP2R2A|5520',
#  'PPP2R1B|5519',
#  'PPP3CB|5532',
#  'PPP3CC|5533',
#  'PPP3R1|5534',
#  'PPPDE2|27351',
#  'PPY2|23614',
#  'PPWD1|23398',
#  'PPTC7|160760',
#  'PPT2|9374',
#  'PPT1|5538',
#  'PPRC1|23082',
#  'PPP6C|5537',
#  'PPP3R2|5535',
#  'PPP5C|5536',
#  'PPP4R4|57718',
#  'PPP4R2|151987',
#  'PPP4R1|9989',
#  'PPP4R1L|55370',
#  'PPP4C|5531',
#  'PRDM11|56981',
#  'PRDM12|59335',
#  'PRDM13|59336',
#  'PRICKLE3|4007',
#  'PRKAR1B|5575',
#  'PRKAR1A|5573',
#  'PRKAG3|53632',
#  'PRKAG2|51422',
#  'PRKAG1|5571',
#  'PRKACG|5568',
#  'PRKACB|5567',
#  'PRKACA|5566',
#  'PRKAB2|5565',
#  'PRKAB1|5564',
#  'PRKAA1|5562',
#  'PRINS|100169750',
#  'PRIMA1|145270',
#  'PRIM2|5558',
#  'PRIM1|5557',
#  'PRKAR2A|5576',
#  'PRKAR2B|5577',
#  'PRKCA|5578',
#  'PRKCSH|5589',
#  'PRKG1|5592',
#  'PRKDC|5591',
#  'PRKD3|23683',
#  'PRKD2|25865',
#  'PRKD1|5587',
#  'PRKCZ|5590',
#  'PRKCQ|5588',
#  'PRKCB|5579',
#  'PRKCI|5584',
#  'PRKCH|5583',
#  'PRKCG|5582',
#  'PRKCE|5581',
#  'PRKCD|5580',
#  'PRKCDBP|112464',
#  'PRICKLE4|29964',
#  'PRICKLE2|166336',
#  'PRDM14|63978',
#  'PRICKLE1|144165',
#  'PRDX5|25824',
#  'PRDX4|10549',
#  'PRDX3|10935',
#  'PRDX2|7001',
#  'PRDX1|5052',
#  'PRDM9|56979',
#  'PRDM8|56978',
#  'PRDM7|11105',
#  'PRDM6|93166',
#  'PRDM5|11107',
#  'PRDM4|11108',
#  'PRDM2|7799',
#  'PRDM1|639',
#  'PRDM16|63976',
#  'PRDM15|63977',
#  'PRDX6|9588',
#  'PREB|10113',
#  'PRELID1|27166',
#  'PRG2|5553',
#  'PRIC285|85441',
#  'PRHOXNB|646625',
#  'PRH2|5555',
#  'PRH1|5554',
#  'PRG4|10216',
#  'PRG3|10394',
#  'PRG1|23574',
#  'PRELID2|153768',
#  'PRF1|5551',
#  'PREX2|80243',
#  'PREX1|57580',
#  'PREP|5550',
#  'PREPL|9581',
#  'PRELP|5549',
#  'PPP2R1A|5518',
#  'PPP2CA|5515',
#  'POM121|9883',
#  'PPAPDC2|403313',
#  'PPAPDC1A|196051',
#  'PPAP2C|8612',
#  'PPAP2B|8613',
#  'PPAP2A|8611',
#  'PPAN|56342',
#  'PPAN-P2RY11|692312',
#  'PPA2|27068',
#  'PPA1|5464',
#  'PP14571|100130449',
#  'POU6F2|11281',
#  'POU6F1|5463',
#  'POU5F2|134187',
#  'POU5F1|5460',
#  'POU5F1B|5462',
#  'POU4F3|5459',
#  'PPAPDC1B|84513',
#  'PPAPDC3|84814',
#  'PPP1R9B|84687',
#  'PPARA|5465',
#  'PPFIA3|8541',
#  'PPFIA2|8499',
#  'PPFIA1|8500',
#  'PPEF2|5470',
#  'PPEF1|5475',
#  'PPDPF|79144',
#  'PPCS|79717',
#  'PPCDC|60490',
#  'PPBP|5473',
#  'PPBPL2|10895',
#  'PPAT|5471',
#  'PPARG|5468',
#  'PPARGC1B|133522',
#  'PPARGC1A|10891',
#  'PPARD|5467',
#  'POU4F2|5458',
#  'POU4F1|5457',
#  'POU3F4|5456',
#  'POU3F3|5455',
#  'POPDC3|64208',
#  'POPDC2|64091',
#  'POP7|10248',
#  'POP5|51367',
#  'POP4|10775',
#  'POP1|10940',
#  'PON3|5446',
#  'PON2|5445',
#  'PON1|5444',
#  'POMZP3|22932',
#  'POMT2|29954',
#  'POMT1|10585',
#  'POMP|51371',
#  'POMGNT1|55624',
#  'POMC|5443',
#  'PORCN|64840',
#  'POSTN|10631',
#  'POT1|25913',
#  'POU1F1|5449',
#  'POU3F2|5454',
#  'POU3F1|5453',
#  'POU2F3|25833',
#  'POU2F2|5452',
#  'POU2F1|5451',
#  'POU2AF1|5450',
#  'POTEH|23784',
#  'POTEA|340441',
#  'POTEG|404785',
#  'POTEF|728378',
#  'POTEE|445582',
#  'POTED|317754',
#  'POTEC|388468',
#  'POTEB|339010',
#  'PPFIA4|8497',
#  'PPFIBP1|8496',
#  'PPFIBP2|8495',
#  'PPOX|5498',
#  'PPP1R15B|84919',
#  'PPP1R15A|23645',
#  'PPP1R14D|54866',
#  'PPP1R14C|81706',
#  'PPP1R14B|26472',
#  'PPP1R14A|94274',
#  'PPP1R13L|10848',
#  'PPP1R13B|23368',
#  'PPP1R12C|54776',
#  'PPP1R12B|4660',
#  'PPP1R12A|4659',
#  'PPP1R11|6992',
#  'PPP1R10|5514',
#  'PPP1CC|5501',
#  'PPP1CB|5500',
#  'PPP1R16A|84988',
#  'PPP1R16B|26051',
#  'PPP1R1A|5502',
#  'PPP1R3C|5507',
#  'PPP1R8|5511',
#  'PPP1R7|5510',
#  'PPP1R3G|648791',
#  'PPP1R3F|89801',
#  'PPP1R3E|90673',
#  'PPP1R3D|5509',
#  'PPP1R3B|79660',
#  'PPP1R1B|84152',
#  'PPP1R3A|5506',
#  'PPP1R2|5504',
#  'PPP1R2P9|80316',
#  'PPP1R2P3|153743',
#  'PPP1R2P1|5505',
#  'PPP1R1C|151242',
#  'PPP1CA|5499',
#  'PPME1|51400',
#  'PPHLN1|51535',
#  'PPM1N|147699',
#  'PPIL1|51645',
#  'PPIH|10465',
#  'PPIG|9360',
#  'PPIF|10105',
#  'PPIE|10450',
#  'PPIEL|728448',
#  'PPID|5481',
#  'PPIC|5480',
#  'PPIB|5479',
#  'PPIA|5478',
#  'PPIAL4G|644591',
#  'PPIAL4E|730262',
#  'PPIAL4D|645142',
#  'PPIAL4C|653598',
#  'PPIAL4B|653505',
#  'PPIL2|23759',
#  'PPIL3|53938',
#  'PPIL4|85313',
#  'PPM1F|9647',
#  'PPM1M|132160',
#  'PPM1L|151742',
#  'PPM1K|152926',
#  'PPM1J|333926',
#  'PPM1H|57460',
#  'PPM1G|5496',
#  'PPM1E|22843',
#  'PPIL5|122769',
#  'PPM1B|5495',
#  'PPM1A|5494',
#  'PPL|5493',
#  'PPIP5K2|23262',
#  'PPIP5K1|9677',
#  'PPIL6|285755',
#  'PLEKHG4B|153478',
#  'PKN2|5586',
#  'PLEKHG3|26030',
#  'PDE7A|5150',
#  'PDGFB|5155',
#  'PDGFA|5154',
#  'PDF|64146',
#  'PDE9A|5152',
#  'PDE8B|8622',
#  'PDE8A|5151',
#  'PDE7B|27115',
#  'PDE6H|5149',
#  'PDGFD|80310',
#  'PDE6G|5148',
#  'PDE6D|5147',
#  'PDE6C|5146',
#  'PDE6B|5158',
#  'PDE6A|5145',
#  'PDE5A|8654',
#  'PDE4D|5144',
#  'PDGFC|56034',
#  'PDGFRA|5156',
#  'PDLIM3|27295',
#  'PDIA6|10130',
#  'PDLIM1|9124',
#  'PDK4|5166',
#  'PDK3|5165',
#  'PDK2|5164',
#  'PDK1|5163',
#  'PDILT|204474',
#  'PDIK1L|149420',
#  'PDIA5|10954',
#  'PDGFRB|5159',
#  'PDIA4|9601',
#  'PDIA3|2923',
#  'PDIA3P|171423',
#  'PDIA2|64714',
#  'PDHX|8050',
#  'PDHB|5162',
#  'PDHA2|5161',
#  'PDE4DIP|9659',
#  'PDE4C|5143',
#  'PDE4B|5142',
#  'PC|5091',
#  'PDCD2|5134',
#  'PDCD2L|84306',
#  'PDCD1|5133',
#  'PDCD1LG2|80380',
#  'PDCD11|22984',
#  'PDCD10|11235',
#  'PDAP1|11333',
#  'PCYT2|5833',
#  'PDE4A|5141',
#  'PCYT1B|9468',
#  'PCYT1A|5130',
#  'PCYOX1|51449',
#  'PCYOX1L|78991',
#  'PCTP|58488',
#  'PCSK9|255738',
#  'PCSK7|9159',
#  'PDCD4|27250',
#  'PDCD5|9141',
#  'PDCD6IP|10015',
#  'PDCD6|10016',
#  'PDE3B|5140',
#  'PDE3A|5139',
#  'PDE2A|5138',
#  'PDE1C|5137',
#  'PDE1B|5153',
#  'PDE1A|5136',
#  'PDE12|201626',
#  'PDE11A|50940',
#  'PDE10A|10846',
#  'PDDC1|347862',
#  'PDC|5132',
#  'PDCL|5082',
#  'PDCL3|79031',
#  'PDCL2|132954',
#  'PDCD7|10081',
#  'PDLIM2|64236',
#  'PDLIM4|8572',
#  'PFDN2|5202',
#  'PEPD|5184',
#  'PET112L|5188',
#  'PES1|23481',
#  'PERP|64065',
#  'PER4|168741',
#  'PER3|8863',
#  'PER2|8864',
#  'PER1|5187',
#  'PENK|5179',
#  'PEX11A|8800',
#  'PEMT|10400',
#  'PELP1|27043',
#  'PELO|53918',
#  'PELI3|246330',
#  'PELI2|57161',
#  'PELI1|57162',
#  'PEG3|5178',
#  'PEX10|5192',
#  'PEX11B|8799',
#  'PDLIM5|10611',
#  'PEX3|8504',
#  'PFAS|5198',
#  'PF4|5196',
#  'PF4V1|5197',
#  'PEX7|5191',
#  'PEX6|5190',
#  'PEX5|5830',
#  'PEX5L|51555',
#  'PEX2|5828',
#  'PEX11G|92960',
#  'PEX26|55670',
#  'PEX1|5189',
#  'PEX19|5824',
#  'PEX16|9409',
#  'PEX14|5195',
#  'PEX13|5194',
#  'PEX12|5193',
#  'PEG3AS|100169890',
#  'PEG10|23089',
#  'PEF1|553115',
#  'PDS5B|23047',
#  'PDXP|57026',
#  'PDXK|8566',
#  'PDXDC2|283970',
#  'PDXDC1|23042',
#  'PDX1|3651',
#  'PDSS2|57107',
#  'PDSS1|23590',
#  'PDS5A|23244',
#  'PECR|55825',
#  'PDRG1|81572',
#  'PDPR|55066',
#  'PDPN|10630',
#  'PDPK1|5170',
#  'PDP2|57546',
#  'PDP1|54704',
#  'PDLIM7|9260',
#  'PDYN|5173',
#  'PDZD11|51248',
#  'PDZD2|23037',
#  'PDZD3|79849',
#  'PECI|10455',
#  'PECAM1|5175',
#  'PEBP4|157310',
#  'PEBP1|5037',
#  'PEAR1|375033',
#  'PEA15|8682',
#  'PDZRN4|29951',
#  'PDZRN3|23024',
#  'PDZK1|5174',
#  'PDZK1P1|728939',
#  'PDZK1IP1|10158',
#  'PDZD9|255762',
#  'PDZD8|118987',
#  'PDZD7|79955',
#  'PDZD4|57595',
#  'PCSK6|5046',
#  'PCSK5|5125',
#  'PCSK4|54760',
#  'PCBD2|84105',
#  'PCDH10|57575',
#  'PCCB|5096',
#  'PCCA|5095',
#  'PCBP4|57060',
#  'PCBP3|54039',
#  'PCBP2|5094',
#  'PCBP1|5093',
#  'PCBD1|5092',
#  'PCDH12|51294',
#  'PCA3|50652',
#  'PBXIP1|57326',
#  'PBX4|80714',
#  'PBX3|5090',
#  'PBX2|5089',
#  'PBX1|5087',
#  'PBRM1|55193',
#  'PCDH11X|27328',
#  'PCDH15|65217',
#  'PCSK2|5126',
#  'PCDHA11|56138',
#  'PCDHA5|56143',
#  'PCDHA4|56144',
#  'PCDHA3|56145',
#  'PCDHA2|56146',
#  'PCDHA1|56147',
#  'PCDHA13|56136',
#  'PCDHA12|56137',
#  'PCDHA10|56139',
#  'PCDH17|27253',
#  'PCDH9|5101',
#  'PCDH8|5100',
#  'PCDH7|5099',
#  'PCDH20|64881',
#  'PCDH1|5097',
#  'PCDH19|57526',
#  'PCDH18|54510',
#  'PBOV1|59351',
#  'PBLD|64081',
#  'PBK|55872',
#  'PARP6|56965',
#  'PARVG|64098',
#  'PARVB|29780',
#  'PARVA|55742',
#  'PART1|25859',
#  'PARS2|25973',
#  'PARP9|83666',
#  'PARP8|79668',
#  'PARP4|143',
#  'PAXIP1|22976',
#  'PARP3|10039',
#  'PARP2|10038',
#  'PARP1|142',
#  'PARP16|54956',
#  'PARP15|165631',
#  'PARP14|54625',
#  'PARP12|64761',
#  'PASD1|139135',
#  'PASK|23178',
#  'PATE1|160065',
#  'PATE2|399967',
#  'PAX9|5083',
#  'PAX8|7849',
#  'PAX7|5081',
#  'PAX6|5080',
#  'PAX5|5079',
#  'PAX4|5078',
#  'PAX3|5077',
#  'PAX2|5076',
#  'PAX1|5075',
#  'PAWR|5074',
#  'PATZ1|23598',
#  'PATL2|197135',
#  'PATL1|219988',
#  'PATE4|399968',
#  'PATE3|100169851',
#  'PCDHA6|56142',
#  'PCDHA7|56141',
#  'PCDHA8|56140',
#  'PCGF3|10336',
#  'PCLO|27445',
#  'PCK2|5106',
#  'PCK1|5105',
#  'PCIF1|63935',
#  'PCID2|55795',
#  'PCGF6|84108',
#  'PCGF5|84333',
#  'PCGF2|7703',
#  'PCDHGB7|56099',
#  'PCGF1|84759',
#  'PCGEM1|64002',
#  'PCF11|51585',
#  'PCDP1|200373',
#  'PCDHGC5|56097',
#  'PCDHGC4|56098',
#  'PCDHGC3|5098',
#  'PCM1|5108',
#  'PCMT1|5110',
#  'PCMTD1|115294',
#  'PCMTD2|55251',
#  'PCSK1|5122',
#  'PCSK1N|27344',
#  'PCP4|5121',
#  'PCP4L1|654790',
#  'PCP2|126006',
#  'PCOTH|542767',
#  'PCOLCE|5118',
#  'PCOLCE2|26577',
#  'PCNX|22990',
#  'PCNXL3|399909',
#  'PCNXL2|80003',
#  'PCNT|5116',
#  'PCNP|57092',
#  'PCNA|5111',
#  'PCNAP1|359806',
#  'PCDHGB8P|56120',
#  'PCDHGB6|56100',
#  'PCDHA9|9752',
#  'PCDHB17|54661',
#  'PCDHB5|26167',
#  'PCDHB4|56131',
#  'PCDHB3|56132',
#  'PCDHB2|56133',
#  'PCDHB1|29930',
#  'PCDHB19P|84054',
#  'PCDHB18|54660',
#  'PCDHB16|57717',
#  'PCDHGB5|56101',
#  'PCDHB15|56121',
#  'PCDHB14|56122',
#  'PCDHB13|56123',
#  'PCDHB12|56124',
#  'PCDHB11|56125',
#  'PCDHAC2|56134',
#  'PCDHAC1|56135',
#  'PCDHB7|56129',
#  'PCDHB8|56128',
#  'PCDHB9|56127',
#  'PCDHGA10|56106',
#  'PCDHGB4|8641',
#  'PCDHGB3|56102',
#  'PCDHGB2|56103',
#  'PCDHGB1|56104',
#  'PCDHGA9|56107',
#  'PCDHGA8|9708',
#  'PCDHGA7|56108',
#  'PCDHGA6|56109',
#  'PCDHGA5|56110',
#  'PCDHGA4|56111',
#  'PCDHGA3|56112',
#  'PCDHGA2|56113',
#  'PCDHGA1|56114',
#  'PCDHGA12|26025',
#  'PCDHGA11|56105',
#  'PFDN1|5201',
#  'PFDN4|5203',
#  'PLEKHG2|64857',
#  'PIWIL3|440822',
#  'PKD1|5310',
#  'PKD1L3|342372',
#  'PKD1L2|114780',
#  'PKD1L1|168507',
#  'PJA2|9867',
#  'PJA1|64219',
#  'PIWIL4|143689',
#  'PIWIL2|55124',
#  'PKD2|5311',
#  'PIWIL1|9271',
#  'PITX3|5309',
#  'PITX2|5308',
#  'PITX1|5307',
#  'PITRM1|10531',
#  'PITPNM3|83394',
#  'PITPNM2|57605',
#  'PKD2L2|27039',
#  'PKDCC|91461',
#  'PLA1A|51365',
#  'PKN1|5585',
#  'PKP4|8502',
#  'PKP3|11187',
#  'PKP2|5318',
#  'PKP1|5317',
#  'PKNOX1|5316',
#  'PKN3|29941',
#  'PRKRA|8575',
#  'PKMYT1|9088',
#  'PKDREJ|10343',
#  'PKM2|5315',
#  'PKLR|5313',
#  'PKIG|11142',
#  'PKIB|5570',
#  'PKIA|5569',
#  'PKHD1|5314',
#  'PKHD1L1|93035',
#  'PITPNM1|9600',
#  'PITPNC1|26207',
#  'PITPNB|23760',
#  'PIKFYVE|200576',
#  'PIN1|5300',
#  'PIN1L|5301',
#  'PIM3|415116',
#  'PIM2|11040',
#  'PIM1|5292',
#  'PILRB|29990',
#  'PILRA|29992',
#  'PIK3R6|146850',
#  'PITPNA|5306',
#  'PIK3R5|23533',
#  'PIK3R4|30849',
#  'PIK3R3|8503',
#  'PIK3R2|5296',
#  'PIK3R1|5295',
#  'PIK3IP1|113791',
#  'PIK3CG|5294',
#  'PIN4|5303',
#  'PINK1|65018',
#  'PINX1|54984',
#  'PION|54103',
#  'PISRT1|140464',
#  'PISD|23761',
#  'PIR|8544',
#  'PIRT|644139',
#  'PIP|5304',
#  'PIPSL|266971',
#  'PIPOX|51268',
#  'PIP5KL1|138429',
#  'PIP5K1P1|206426',
#  'PIP5K1C|23396',
#  'PIP5K1B|8395',
#  'PIP5K1A|8394',
#  'PIP4K2C|79837',
#  'PIP4K2B|8396',
#  'PIP4K2A|5305',
#  'PL-5283|647087',
#  'PLA2G10|8399',
#  'PFDN5|5204',
#  'PLCL1|5334',
#  'PLD3|23646',
#  'PLD2|5338',
#  'PLD1|5337',
#  'PLCXD3|345557',
#  'PLCXD2|257068',
#  'PLCXD1|55344',
#  'PLCL2|23228',
#  'PLCH2|9651',
#  'PLD5|200150',
#  'PLCH1|23007',
#  'PLCG2|5336',
#  'PLCG1|5335',
#  'PLCE1|51196',
#  'PLCD4|84812',
#  'PLCD3|113026',
#  'PLCD1|5333',
#  'PLD4|122618',
#  'PLD6|201164',
#  'PLA2G12A|81579',
#  'PLEKHA7|144100',
#  'PLEKHG1|57480',
#  'PLEKHF2|79666',
#  'PLEKHF1|79156',
#  'PLEKHB2|55041',
#  'PLEKHB1|58473',
#  'PLEKHA9|51054',
#  'PLEKHA8|84725',
#  'PLEKHA6|22874',
#  'PLDN|26258',
#  'PLEKHA5|54477',
#  'PLEKHA4|57664',
#  'PLEKHA3|65977',
#  'PLEKHA2|59339',
#  'PLEKHA1|59338',
#  'PLEK2|26499',
#  'PLEC|5339',
#  'PLCB4|5332',
#  'PLCB3|5331',
#  'PLCB2|5330',
#  'PLA2G2F|64600',
#  'PLA2G5|5322',
#  'PLA2G4F|255189',
#  'PLA2G4E|123745',
#  'PLA2G4D|283748',
#  'PLA2G4C|8605',
#  'PLA2G4A|5321',
#  'PLA2G3|50487',
#  'PLA2G2E|30814',
#  'PLCB1|23236',
#  'PLA2G2D|26279',
#  'PLA2G2C|391013',
#  'PLA2G2A|5320',
#  'PLA2G1B|5319',
#  'PLA2G16|11145',
#  'PLA2G15|23659',
#  'PLA2G12B|84647',
#  'PLA2G6|8398',
#  'PLA2G7|7941',
#  'PLA2R1|22925',
#  'PLAA|9373',
#  'PLBD2|196463',
#  'PLBD1|79887',
#  'PLB1|151056',
#  'PLAU|5328',
#  'PLAUR|5329',
#  'PLAT|5327',
#  'PLAGL2|5326',
#  'PLAG1|5324',
#  'PLAC9|219348',
#  'PLAC8|51316',
#  'PLAC8L1|153770',
#  'PLAC4|191585',
#  'PLAC2|257000',
#  'PLAC1|10761',
#  'PLAC1L|219990',
#  'PIK3CD|5293',
#  'PIK3CB|5291',
#  'PIK3CA|5290',
#  'PGRMC2|10424',
#  'PHAX|51808',
#  'PHACTR4|65979',
#  'PHACTR3|116154',
#  'PHACTR2|9749',
#  'PHACTR1|221692',
#  'PGS1|9489',
#  'PGR|5241',
#  'PGRMC1|10857',
#  'PHC1|1911',
#  'PGP|283871',
#  'PGPEP1|54858',
#  'PGPEP1L|145814',
#  'PGM5P2|595135',
#  'PGM3|5238',
#  'PGM2|55276',
#  'PGM2L1|283209',
#  'PHB|5245',
#  'PHC2|1912',
#  'PIK3C3|5289',
#  'PHF19|26147',
#  'PHF2|5253',
#  'PHF23|79142',
#  'PHF21B|112885',
#  'PHF21A|51317',
#  'PHF20|51230',
#  'PHF20L1|51105',
#  'PHF1|5252',
#  'PHF17|79960',
#  'PHC3|80012',
#  'PHF15|23338',
#  'PHF14|9678',
#  'PHF13|148479',
#  'PHF12|57649',
#  'PHF11|51131',
#  'PHF10|55274',
#  'PHEX|5251',
#  'PGM1|5236',
#  'PGLYRP4|57115',
#  'PGLYRP3|114771',
#  ...]

# %% [markdown]
# ### Plot Feature Importances
#
# The feature importance plot using `plot_feature_importances` will show us the `plot_n` most important features (on a normalized scale where the features sum to 1). It also shows us the cumulative feature importance versus the number of features.
#
# When we plot the feature importances, we can pass in a `threshold` which identifies the number of features required to reach a specified cumulative feature importance. For example, `threshold = 0.99` will tell us the number of features needed to account for 99% of the total importance.

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 40)
# Out:
# 359 features required for 0.99 of cumulative importance

# %% [markdown]
# All of the feature importances are accessible in the `feature_importances` attribute of the `FeatureSelector`

# %%
fs.feature_importances.head(50)
# Out:
#              feature  importance  normalized_importance  cumulative_importance
# 0        ?|100133144         6.7               0.104688               0.104688
# 1           KLK3|354         1.8               0.028125               0.132812
# 2       ACBD7|414149         1.6               0.025000               0.157812
# 3         SFTPB|6439         1.3               0.020313               0.178125
# 4         AACS|65985         1.2               0.018750               0.196875
# 5          KRT8|3856         1.0               0.015625               0.212500
# 6         EPCAM|4072         1.0               0.015625               0.228125
# 7       A4GALT|53947         0.9               0.014063               0.242188
# 8         ABCC8|6833         0.9               0.014063               0.256250
# 9         TNMD|64102         0.7               0.010937               0.267187
# 10     ATP11C|286410         0.7               0.010937               0.278125
# 11        FGD6|55785         0.7               0.010937               0.289062
# 12        LEF1|51176         0.7               0.010937               0.300000
# 13      ABCB5|340273         0.5               0.007812               0.307812
# 14    C1orf116|79098         0.5               0.007812               0.315625
# 15      SFTA2|389376         0.5               0.007812               0.323437
# 16        QPCT|25797         0.5               0.007812               0.331250
# 17     RASL10A|10633         0.4               0.006250               0.337500
# 18          JUP|3728         0.4               0.006250               0.343750
# 19        RLBP1|6017         0.4               0.006250               0.350000
# 20           ?|90288         0.4               0.006250               0.356250
# 21          ?|645851         0.4               0.006250               0.362500
# 22        NR1D1|9572         0.4               0.006250               0.368750
# 23          ACTG2|72         0.4               0.006250               0.375000
# 24          ?|155060         0.4               0.006250               0.381250
# 25          CAV2|858         0.4               0.006250               0.387500
# 26        AAK1|22848         0.3               0.004688               0.392187
# 27     CCDC136|64753         0.3               0.004688               0.396875
# 28     S100PBP|64766         0.3               0.004687               0.401562
# 29        BNC2|54796         0.3               0.004687               0.406250
# 30  LOC401588|401588         0.3               0.004687               0.410937
# 31      B4GALT1|2683         0.3               0.004687               0.415625
# 32     COMTD1|118881         0.3               0.004687               0.420312
# 33        AKT3|10000         0.3               0.004687               0.425000
# 34   C1orf216|127703         0.3               0.004687               0.429687
# 35          BBS1|582         0.3               0.004687               0.434375
# 36       AGR3|155465         0.3               0.004687               0.439062
# 37        DBR1|51163         0.3               0.004687               0.443750
# 38        AP3D1|8943         0.3               0.004687               0.448437
# 39         GNG7|2788         0.3               0.004687               0.453125
# 40     ARL6IP5|10550         0.3               0.004687               0.457812
# 41          LYN|4067         0.2               0.003125               0.460937
# 42       VSIG2|23584         0.2               0.003125               0.464062
# 43        RGS20|8601         0.2               0.003125               0.467187
# 44        PDHA1|5160         0.2               0.003125               0.470312
# 45       SYNGR1|9145         0.2               0.003125               0.473437
# 46       ABCC9|10060         0.2               0.003125               0.476562
# 47        AGR2|10551         0.2               0.003125               0.479687
# 48     ZNF774|342132         0.2               0.003125               0.482812
# 49          ANK1|286         0.2               0.003125               0.485937

# %% [markdown]
# We could use these results to select only the 'n' most important features. For example, if we want the top 100 most importance, we could do the following.

# %%
one_hundred_features = list(fs.feature_importances.loc[:99, 'feature'])
len(one_hundred_features)
# Out:
# 100

# %% [markdown]
# # 5. Low Importance Features
#
# This method builds off the feature importances from the gradient boosting machine (`identify_zero_importance` must be run first) by finding the lowest importance features not needed to reach a specified cumulative total feature importance. For example, if we pass in 0.99, this will find the lowest important features that are not needed to reach 99% of the total feature importance.
#
# When using this method, we must have already run `identify_zero_importance` and need to pass in a `cumulative_importance` that accounts for that fraction of total feature importance.
#
# __Note of caution__: this method builds on the gradient boosting model features importances and again is non-deterministic. I advise running these two methods several times with varying parameters and testing each resulting set of features rather than picking one number and sticking to it.

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 358 features required for cumulative importance of 0.99 after one hot encoding.
# 20173 features do not contribute to cumulative importance of 0.99.

# %% [markdown]
# The low importance features to remove are those that do not contribute to the specified cumulative importance. These are also available in the `ops` dictionary.

# %%
low_importance_features = fs.ops['low_importance']
low_importance_features[:5]
# Out:
# ['?|280660', 'BAG2|9532', '?|100134869', 'RTTN|25914', 'B3GNT6|192134']

# %% [markdown]
# # Removing Features
#
# Once we have identified the features to remove, we have a number of ways to drop the features. We can access any of the feature lists in the `removal_ops` dictionary and remove the columns manually. We also can use the `remove` method, passing in the methods that identified the features we want to remove.
#
# This method returns the resulting data which we can then use for machine learning. The original data will still be accessible in the `data` attribute of the Feature Selector.
#
# __Be careful__ of the methods used for removing features! It's a good idea to inspect the features that will be removed before using the `remove` function.

# %%
fs.identify_missing(missing_threshold=0)
# Out:
# 0 features with greater than 0.00 missing values.

# %%
train_no_missing = fs.remove(methods = ['missing'])
# Out:
# Removed 0 features.

# %%
train_zero = fs.remove(methods = ['zero_importance'])
# Out:
# Removed 20166 features.

# %% [markdown]
# To remove the features from all of the methods, pass in `method='all'`. Before we do this, we can check how many features will be removed using `check_removal`. This returns a list of all the features that have been idenfitied for removal.

# %%
all_to_remove = fs.check_removal()
all_to_remove
# Out:
# Total of 20173 features identified for removal
# ['PSG5|5673',
#  'GATAD2B|57459',
#  'MUT|4594',
#  'TMEM165|55858',
#  'FLT4|2324',
#  'SLITRK6|84189',
#  'C9orf91|203197',
#  'ARHGAP11B|89839',
#  'DYNLT3|6990',
#  'FAM150A|389658',
#  'ADO|84890',
#  'GRTP1|79774',
#  'FKBP10|60681',
#  'OTUD7A|161725',
#  'PTPLAD2|401494',
#  'MYO5C|55930',
#  'SLC7A11|23657',
#  'SMCP|4184',
#  'C1orf26|54823',
#  'NUP155|9631',
#  'RHCG|51458',
#  'FBXO16|157574',
#  'HPX|3263',
#  'RPL39|6170',
#  'THY1|7070',
#  'PPP3CA|5530',
#  'CELF4|56853',
#  'FLJ40434|163742',
#  'CAPS2|84698',
#  'GPR137|56834',
#  'H2AFY|9555',
#  'C9orf6|54942',
#  'C9orf21|195827',
#  'ARID2|196528',
#  'LRRN4|164312',
#  'GUK1|2987',
#  'C17orf82|388407',
#  'PCSK9|255738',
#  'TSLP|85480',
#  'GPR1|2825',
#  'FAM25B|100132929',
#  'MTNR1B|4544',
#  'TMTC1|83857',
#  'KCNN2|3781',
#  'CD274|29126',
#  'DSE|29940',
#  'MMP14|4323',
#  'SATL1|340562',
#  'STOML1|9399',
#  'DNTTIP2|30836',
#  'GABRB3|2562',
#  'SFTPC|6440',
#  'PF4|5196',
#  'ACCSL|390110',
#  'HIST2H3D|653604',
#  'LY6K|54742',
#  'PDLIM5|10611',
#  'SPTLC1|10558',
#  'NAIF1|203245',
#  'PDHA2|5161',
#  'ZRANB2|9406',
#  'RAB25|57111',
#  'NXF5|55998',
#  'FOXE3|2301',
#  'HSD17B3|3293',
#  'CD36|948',
#  'TIGD7|91151',
#  'ENDOG|2021',
#  'ZBTB4|57659',
#  'NPC1|4864',
#  'CST9|128822',
#  'GPR172B|55065',
#  'FAM195B|348262',
#  'CES8|283848',
#  'LOC285359|285359',
#  'CDK19|23097',
#  'HHLA3|11147',
#  'SLC22A6|9356',
#  'ZCCHC13|389874',
#  'TNFRSF10B|8795',
#  'VPS13C|54832',
#  'PRTFDC1|56952',
#  'C1orf228|339541',
#  'FGD4|121512',
#  'FBXO38|81545',
#  'FAM182B|728882',
#  'ASCC1|51008',
#  'NT5E|4907',
#  'TNFRSF12A|51330',
#  'OR6C4|341418',
#  'CCDC94|55702',
#  'RGS17|26575',
#  'DECR2|26063',
#  'MANEAL|149175',
#  'RASEF|158158',
#  'DYNLRB2|83657',
#  'PDIA5|10954',
#  'ARID3B|10620',
#  'C3orf24|115795',
#  'TRIM54|57159',
#  'SRP14|6727',
#  'ACTR10|55860',
#  'SNAR-E|100170220',
#  'TFPT|29844',
#  'HRASLS5|117245',
#  'CHD3|1107',
#  'LOC100133920|100133920',
#  'LOC360030|360030',
#  'IFT52|51098',
#  'XPO5|57510',
#  'NAA10|8260',
#  'SFN|2810',
#  'STK4|6789',
#  'PARP3|10039',
#  'PABPC4|8761',
#  'RET|5979',
#  'LOC100133612|100133612',
#  'NOS3|4846',
#  'C14orf2|9556',
#  'VPS4A|27183',
#  'CARD17|440068',
#  'WBSCR16|81554',
#  'ZG16|653808',
#  'CT45A2|728911',
#  'GPR56|9289',
#  'PSG3|5671',
#  'FAM100A|124402',
#  'KIN|22944',
#  'CPSF3|51692',
#  'ZNF514|84874',
#  'IPW|3653',
#  'FEM1C|56929',
#  'FAM43A|131583',
#  'POMC|5443',
#  'INO80D|54891',
#  'GK3P|2713',
#  'CAMTA2|23125',
#  'RING1|6015',
#  'EIF2B1|1967',
#  'PRKAB1|5564',
#  'PNP|4860',
#  'MACF1|23499',
#  'CXorf66|347487',
#  'C5orf43|643155',
#  '?|57714',
#  'POM121L9P|29774',
#  'RAPGEF3|10411',
#  'C18orf54|162681',
#  'SPANXN4|441525',
#  'PIAS3|10401',
#  'SLC35B2|347734',
#  'GTF2H5|404672',
#  'LMAN1L|79748',
#  'FLJ42875|440556',
#  'KCNA2|3737',
#  'PRKCB|5579',
#  'TPTE2|93492',
#  'SSX5|6758',
#  'ZNF799|90576',
#  'NXNL1|115861',
#  'SRFBP1|153443',
#  'RAGE|5891',
#  'ACMSD|130013',
#  'TTTY19|252952',
#  'NOTCH2NL|388677',
#  'DNAJB7|150353',
#  'ARVCF|421',
#  'C10orf111|221060',
#  'C10orf91|170393',
#  'PAX4|5078',
#  'SPON2|10417',
#  'WIZ|58525',
#  'ANKRD11|29123',
#  'SSR1|6745',
#  'NDUFA4|4697',
#  'CPT2|1376',
#  'THRAP3|9967',
#  'SLIT2|9353',
#  'LYPD5|284348',
#  'OR8J3|81168',
#  'CEP57|9702',
#  'NCAM2|4685',
#  'KLHL4|56062',
#  'LOC100134868|100134868',
#  'TMEM168|64418',
#  'C15orf38|348110',
#  'ZNF700|90592',
#  'CASZ1|54897',
#  'PHF10|55274',
#  'PGAM2|5224',
#  'FMR1NB|158521',
#  'RGPD8|727851',
#  'OTP|23440',
#  'C11orf2|738',
#  'EXOSC3|51010',
#  'FBXL12|54850',
#  'ADAM9|8754',
#  'B4GALT6|9331',
#  'ISOC1|51015',
#  'ASPN|54829',
#  'POFUT1|23509',
#  'MAP1A|4130',
#  'PASK|23178',
#  'C1orf43|25912',
#  'SOBP|55084',
#  'DDX39|10212',
#  'POLG|5428',
#  'KIF2A|3796',
#  'CYBA|1535',
#  'ZNF521|25925',
#  'PRR7|80758',
#  'ZNF461|92283',
#  'SCARNA6|677772',
#  'ARMC4|55130',
#  'HEXIM1|10614',
#  'SPIN1|10927',
#  'MRAP2|112609',
#  'MRPL21|219927',
#  'C1S|716',
#  'C20orf185|359710',
#  'PRLR|5618',
#  'CRYGN|155051',
#  'SYCE2|256126',
#  'IRF1|3659',
#  'SLC41A3|54946',
#  'C17orf63|55731',
#  'SNX27|81609',
#  'IL4I1|259307',
#  'STARD5|80765',
#  'DBF4B|80174',
#  'GEM|2669',
#  'OR5D18|219438',
#  'GABRA2|2555',
#  'WIPF2|147179',
#  'FAM176B|55194',
#  'SEPT12|124404',
#  'GPR182|11318',
#  'ZNF233|353355',
#  'VIL1|7429',
#  'PNRC1|10957',
#  'GEMIN4|50628',
#  'SLC38A9|153129',
#  'HIST1H1E|3008',
#  'PRPF6|24148',
#  'ATRX|546',
#  'FTSJ1|24140',
#  'VMAC|400673',
#  'ZNF79|7633',
#  'QSOX1|5768',
#  'MYH7B|57644',
#  'POPDC2|64091',
#  'MRPL22|29093',
#  'VTRNA1-2|56663',
#  'ZCWPW1|55063',
#  'OR2A12|346525',
#  'AMFR|267',
#  'MRGPRG|386746',
#  'PDE6C|5146',
#  'SLC7A13|157724',
#  'LRRTM1|347730',
#  'FKBP15|23307',
#  'RND1|27289',
#  'RXFP3|51289',
#  'GRID2IP|392862',
#  'HOXA1|3198',
#  'TGFB3|7043',
#  'CEP170L|645455',
#  'GRK5|2869',
#  'ATP6V0E1|8992',
#  'DRG1|4733',
#  'C11orf54|28970',
#  'KIAA0494|9813',
#  'HAUS3|79441',
#  'GRK4|2868',
#  'PARD6G|84552',
#  'KCNE1L|23630',
#  'MYO7B|4648',
#  'SIGLEC9|27180',
#  'ASH1L|55870',
#  'PAQR5|54852',
#  'INSM2|84684',
#  'LOC727896|727896',
#  'CLPS|1208',
#  'ANKLE2|23141',
#  'MEGF6|1953',
#  'RFC1|5981',
#  'CCDC154|645811',
#  'EXOC6|54536',
#  'INS-IGF2|723961',
#  'HFE2|148738',
#  'LRRC47|57470',
#  'CCDC47|57003',
#  'ZNF746|155061',
#  'RAP1GAP|5909',
#  'MX1|4599',
#  'LOC90784|90784',
#  'STH|246744',
#  'KIAA1279|26128',
#  'WBP11P1|441818',
#  'NAF1|92345',
#  'HSPC072|29075',
#  'ECSIT|51295',
#  'USP32|84669',
#  'SACS|26278',
#  'FAM24A|118670',
#  'ODZ4|26011',
#  'RAG2|5897',
#  'NDUFA1|4694',
#  'SNX33|257364',
#  'PLK1S1|55857',
#  'OR4F6|390648',
#  'VSX2|338917',
#  'SURF1|6834',
#  'NLRP13|126204',
#  'CACNA1F|778',
#  'SOD1|6647',
#  'RASGRF2|5924',
#  'THEMIS|387357',
#  'MRPS14|63931',
#  'THRA|7067',
#  'TAS2R3|50831',
#  'ENPP1|5167',
#  'ABTB1|80325',
#  'SMARCAL1|50485',
#  'RALGAPA2|57186',
#  'LOC100169752|100169752',
#  'PCDHGB7|56099',
#  'PDZK1|5174',
#  'SPANXE|171489',
#  'C6orf176|90632',
#  'HS6ST1|9394',
#  'ZBTB8B|728116',
#  'PSMB7|5695',
#  'AADACL2|344752',
#  'COMMD4|54939',
#  'GGA3|23163',
#  'LOC115110|115110',
#  'PSMB6|5694',
#  'FAM175A|84142',
#  'HAPLN4|404037',
#  'SLC22A20|440044',
#  'CCNYL1|151195',
#  'COX7A2|1347',
#  'RPA2|6118',
#  'SPRN|503542',
#  'PAIP2B|400961',
#  'ETHE1|23474',
#  'TREX1|11277',
#  'ASPG|374569',
#  'VPS39|23339',
#  'FGF6|2251',
#  'E2F7|144455',
#  'CTHRC1|115908',
#  'MTHFD1|4522',
#  'EXOSC7|23016',
#  'GPR137C|283554',
#  'ZNF187|7741',
#  'SNORD115-4|100033441',
#  'ZNF835|90485',
#  'ESX1|80712',
#  'C9orf169|375791',
#  'LATS2|26524',
#  'LOC286238|286238',
#  'P2RX2|22953',
#  'ADRA1D|146',
#  'VTCN1|79679',
#  'CCDC88A|55704',
#  'WEE1|7465',
#  'LBR|3930',
#  'OR8A1|390275',
#  'OR2A9P|441295',
#  'PPM1A|5494',
#  'ZPBP2|124626',
#  'HIVEP3|59269',
#  'SLCO1B1|10599',
#  'ING2|3622',
#  'FRS2|10818',
#  'SLC26A8|116369',
#  'RPL4|6124',
#  'IER2|9592',
#  'SYT14L|401135',
#  'LOC729668|729668',
#  'CAMK1|8536',
#  'PLSCR2|57047',
#  'ZNF138|7697',
#  'AJAP1|55966',
#  'AP1S3|130340',
#  'RPLP0P2|113157',
#  'C1GALT1|56913',
#  'TMEM79|84283',
#  'OR3A2|4995',
#  'HLA-H|3136',
#  'TRIOBP|11078',
#  'FAM101B|359845',
#  'PDIA3|2923',
#  'KNTC1|9735',
#  'TNIP3|79931',
#  'C20orf12|55184',
#  'GRIP1|23426',
#  'NUDT15|55270',
#  'STAU2|27067',
#  'KDM4A|9682',
#  'C10orf84|63877',
#  'SIGIRR|59307',
#  'PTPRG|5793',
#  'IGSF3|3321',
#  'RTN4|57142',
#  'NAP1L2|4674',
#  'CLIP3|25999',
#  'ERP27|121506',
#  'RGMA|56963',
#  'C21orf82|114036',
#  'SDR16C5|195814',
#  'EIF4ENIF1|56478',
#  'LOC157627|157627',
#  'RPS6KB2|6199',
#  'RPL14|9045',
#  'TADA2B|93624',
#  'GTF2IRD2|84163',
#  'PIGC|5279',
#  'MYO1C|4641',
#  'DDT|1652',
#  'NOS1AP|9722',
#  'POLR2G|5436',
#  'NAE1|8883',
#  'ALCAM|214',
#  'RTN3|10313',
#  'ST3GAL6|10402',
#  'LIF|3976',
#  'CERCAM|51148',
#  'SIX2|10736',
#  'EPB42|2038',
#  'FCGR1A|2209',
#  'C1orf122|127687',
#  'GABRD|2563',
#  'PLIN1|5346',
#  'MGAT1|4245',
#  'LOC151300|151300',
#  'RASL10B|91608',
#  'VAX2|25806',
#  'SYCE1L|100130958',
#  'TKT|7086',
#  'ZIK1|284307',
#  'SIRT1|23411',
#  'ZNF830|91603',
#  'ITGB4|3691',
#  'PTPRB|5787',
#  'VAT1L|57687',
#  'NOL12|79159',
#  'UGT2B28|54490',
#  'RPL30|6156',
#  'BRIX1|55299',
#  'PCP4|5121',
#  'ZNF80|7634',
#  'SOS1|6654',
#  'GAL3ST1|9514',
#  'TBCD|6904',
#  'INGX|27160',
#  'BRF2|55290',
#  'MDC1|9656',
#  'DAPK2|23604',
#  'HOXA10|3206',
#  'TTLL13|440307',
#  'C11orf42|160298',
#  'CDC6|990',
#  'APOLD1|81575',
#  'C3AR1|719',
#  'FAM129A|116496',
#  'MGC27382|149047',
#  'C22orf29|79680',
#  'IL29|282618',
#  'C19orf40|91442',
#  'EFCAB3|146779',
#  'LDHA|3939',
#  'TMEM14C|51522',
#  'CCT6B|10693',
#  'LOC100288778|100288778',
#  'ACVR1C|130399',
#  'LOC284276|284276',
#  'FKBP2|2286',
#  'ZNF479|90827',
#  'LMO4|8543',
#  'DYX1C1|161582',
#  'SPIC|121599',
#  'INSL3|3640',
#  'L3MBTL|26013',
#  'GPX2|2877',
#  'MT1F|4494',
#  'ZMPSTE24|10269',
#  'C2orf57|165100',
#  'FRMPD2|143162',
#  'MELK|9833',
#  'NONO|4841',
#  'LDOC1L|84247',
#  'ADIG|149685',
#  'NCAPD3|23310',
#  'TRIM4|89122',
#  'PPP1R16A|84988',
#  'RBMY1B|378948',
#  'PRHOXNB|646625',
#  'FSTL4|23105',
#  'C17orf99|100141515',
#  'BOD1L|259282',
#  'LOC100130691|100130691',
#  'C17orf107|100130311',
#  'RABGGTA|5875',
#  'CDKAL1|54901',
#  'BCAR1|9564',
#  'STOM|2040',
#  'ING3|54556',
#  'FLJ26850|400710',
#  'C10orf54|64115',
#  'C21orf122|728039',
#  'PRR23A|729627',
#  'SNAR-F|100126781',
#  'ALDH3B2|222',
#  'ETNK1|55500',
#  'SCFD2|152579',
#  'SH3PXD2B|285590',
#  'LNX2|222484',
#  'OR4K13|390433',
#  'DNAJC30|84277',
#  'UBE2I|7329',
#  'SSX3|10214',
#  'KIF1C|10749',
#  'SNORA11E|100124542',
#  'CXCR2P1|3580',
#  'HSD11B1|3290',
#  'CBR1|873',
#  'TMEM92|162461',
#  'NDUFAF2|91942',
#  'TMEM161A|54929',
#  'FABP2|2169',
#  'SOX2OT|347689',
#  'PATL2|197135',
#  'MYBL1|4603',
#  'CASC2|255082',
#  'ZSWIM7|125150',
#  'GRID2|2895',
#  'MUTYH|4595',
#  'RAB32|10981',
#  'PRIM1|5557',
#  'SLFN5|162394',
#  'SNORD96A|619571',
#  'C14orf142|84520',
#  'C4orf3|401152',
#  'PCBP4|57060',
#  'ST6GALNAC4|27090',
#  'ZPLD1|131368',
#  'HAP1|9001',
#  'BTN3A1|11119',
#  'CLPP|8192',
#  'CCDC46|201134',
#  'ZMYM5|9205',
#  'SNAPIN|23557',
#  'BMPER|168667',
#  'FLCN|201163',
#  'ADAMTS2|9509',
#  'ZNF18|7566',
#  'IGSF9|57549',
#  'LRRC49|54839',
#  'ZNF775|285971',
#  'PROCA1|147011',
#  'SLC15A1|6564',
#  'PNPLA2|57104',
#  'ZNF556|80032',
#  'KLK14|43847',
#  'NCRNA00052|145978',
#  'CACYBP|27101',
#  'GUSB|2990',
#  'SLC35D2|11046',
#  'GGPS1|9453',
#  'LOC100129935|100129935',
#  'PTK7|5754',
#  'PAFAH1B3|5050',
#  'SLC10A2|6555',
#  'MZF1|7593',
#  'NCRNA00188|125144',
#  'IL28A|282616',
#  'CELSR1|9620',
#  'LOC647979|647979',
#  'SLC2A8|29988',
#  'C17orf74|201243',
#  'CPT1B|1375',
#  'INPP5E|56623',
#  'NEK1|4750',
#  'C12orf26|84190',
#  'TPI1P2|286016',
#  'CTAG2|30848',
#  'CSRP1|1465',
#  'NOL3|8996',
#  'CD14|929',
#  'KRTAP4-8|728224',
#  'WDR91|29062',
#  'C12orf36|283422',
#  'SOCS6|9306',
#  'REEP1|65055',
#  'PRMT10|90826',
#  'GABRA3|2556',
#  'PSEN2|5664',
#  'CARKD|55739',
#  'NUDT21|11051',
#  'PRPF40A|55660',
#  'SMTNL2|342527',
#  'UCK1|83549',
#  'MON2|23041',
#  'OTOL1|131149',
#  'ELK4|2005',
#  'PGBD1|84547',
#  'TTN|7273',
#  'GRXCR2|643226',
#  'ARPP19|10776',
#  'PARG|8505',
#  'ZWINT|11130',
#  'LOC441666|441666',
#  'GOLGA2P3|401634',
#  'FLJ43663|378805',
#  'NOX5|79400',
#  'PPID|5481',
#  'WDR24|84219',
#  'CRHBP|1393',
#  'MUCL1|118430',
#  'BUB1|699',
#  'GPNMB|10457',
#  'UBE2U|148581',
#  'GIMAP5|55340',
#  'UGGT1|56886',
#  'HSPA2|3306',
#  'ADM|133',
#  'POC1B|282809',
#  'SLC2A1|6513',
#  'B4GALNT2|124872',
#  'TMEM74|157753',
#  'C11orf48|79081',
#  'LOC100188947|100188947',
#  'L3MBTL2|83746',
#  'C8orf56|157556',
#  'ZNF497|162968',
#  'GABARAPL3|23766',
#  'CSNK1G2|1455',
#  'CCDC92|80212',
#  'CASKIN1|57524',
#  'KBTBD11|9920',
#  'NAA15|80155',
#  'VCAN|1462',
#  'DKK2|27123',
#  'MOBKL2A|126308',
#  'MRPS18C|51023',
#  'DCBLD2|131566',
#  'FBXW7|55294',
#  'RPL21P44|402176',
#  'RS1|6247',
#  'SNORD114-3|767579',
#  'OR10S1|219873',
#  'CD1B|910',
#  'METTL3|56339',
#  'AGPAT3|56894',
#  'CDK17|5128',
#  'C17orf28|283987',
#  'RNF20|56254',
#  'LOC729609|729609',
#  'SLC6A9|6536',
#  'CORIN|10699',
#  'TBX19|9095',
#  'SLC4A11|83959',
#  'FAM136A|84908',
#  'PPARA|5465',
#  'NBR2|10230',
#  'COX17|10063',
#  'DLG2|1740',
#  'POPDC3|64208',
#  'CDHR5|53841',
#  'AKAP2|11217',
#  'RHOXF1|158800',
#  'TEX264|51368',
#  'WISP2|8839',
#  'SULT1B1|27284',
#  'GLDC|2731',
#  'TACR2|6865',
#  'OR2W1|26692',
#  'TBC1D20|128637',
#  'ARNT2|9915',
#  'CYTL1|54360',
#  'ZNF74|7625',
#  'YPEL2|388403',
#  'TAF1L|138474',
#  'ZFAND3|60685',
#  'SYT11|23208',
#  'GPR128|84873',
#  'ARSG|22901',
#  'HKR1|284459',
#  'C12orf41|54934',
#  'SNORD20|6082',
#  'SPINT2|10653',
#  'ZNF826|664701',
#  'MPP1|4354',
#  'RAET1L|154064',
#  'B3GALT1|8708',
#  'HIST1H2BH|8345',
#  'GSTM4|2948',
#  'NINJ2|4815',
#  'LOC730668|730668',
#  'TEDDM1|127670',
#  'EIF2B3|8891',
#  'MAS1|4142',
#  'EXOSC1|51013',
#  'MGC72080|389538',
#  'TMEM141|85014',
#  'C11orf51|25906',
#  'TRMU|55687',
#  'WHSC1L1|54904',
#  'ZNF277|11179',
#  'LENG1|79165',
#  'ZCCHC8|55596',
#  'LCLAT1|253558',
#  'UMODL1|89766',
#  'LIMA1|51474',
#  'CDC34|997',
#  'SKIV2L|6499',
#  'SPAST|6683',
#  'GABRA5|2558',
#  'TMC3|342125',
#  'KIAA1370|56204',
#  'KIAA0368|23392',
#  'MGA|23269',
#  'SETD3|84193',
#  'HINT2|84681',
#  'KCND3|3752',
#  'KLHDC8A|55220',
#  'KLK8|11202',
#  'ZNF771|51333',
#  'LRRC3|81543',
#  'NPIPL3|23117',
#  'FAM111B|374393',
#  'PSG2|5670',
#  'CYP2A13|1553',
#  'PRAMEF1|65121',
#  'ENHO|375704',
#  'GPR81|27198',
#  'MMP12|4321',
#  'ZNF420|147923',
#  'ACOT7|11332',
#  'WFDC13|164237',
#  'CSAG1|158511',
#  'HIATL1|84641',
#  'PDK1|5163',
#  'PPP3R1|5534',
#  'EML6|400954',
#  'NEU4|129807',
#  'TRIM48|79097',
#  'LOC338588|338588',
#  'CYCS|54205',
#  'GCM1|8521',
#  'SAMD14|201191',
#  'ANAPC16|119504',
#  'ZC3H7A|29066',
#  'OR4A5|81318',
#  'SPRR2E|6704',
#  'PLK3|1263',
#  'BMP15|9210',
#  'WASF2|10163',
#  'TPRKB|51002',
#  'SLC43A1|8501',
#  'NALCN|259232',
#  'DLK1|8788',
#  'RGS14|10636',
#  'TLX2|3196',
#  'MLNR|2862',
#  'FAM25A|643161',
#  'WDR11|55717',
#  'ASAM|79827',
#  'PBRM1|55193',
#  'VTN|7448',
#  'HAMP|57817',
#  'APOBEC1|339',
#  'FAM35B2|439965',
#  'PDZK1IP1|10158',
#  'KRTAP25-1|100131902',
#  'CX3CR1|1524',
#  'C11orf49|79096',
#  'FAM75A3|727830',
#  'ATP6V0C|527',
#  'KLHL8|57563',
#  'RAB3D|9545',
#  'SLC14A1|6563',
#  'DGCR11|25786',
#  'BAG1|573',
#  'RLN1|6013',
#  'GAGE12J|729396',
#  'PLEKHO2|80301',
#  'HNRNPA3|220988',
#  'LOC283050|283050',
#  'ZMYM4|9202',
#  'C6orf203|51250',
#  'LBX1|10660',
#  'TMPRSS2|7113',
#  'FAM111A|63901',
#  'C17orf49|124944',
#  'LOC344967|344967',
#  'KC6|641516',
#  'RNASE2|6036',
#  'TCEA1|6917',
#  'COG1|9382',
#  'EIF5A2|56648',
#  'C2orf89|129293',
#  'SEC22B|9554',
#  'HTR3A|3359',
#  'NCRNA00081|92482',
#  'CCDC88B|283234',
#  'ARSK|153642',
#  'ACTR1B|10120',
#  'SMS|6611',
#  'ARL2|402',
#  'PGAP3|93210',
#  'MRPL9|65005',
#  'DOK3|79930',
#  'POLM|27434',
#  'APOC1|341',
#  'TEP1|7011',
#  'CCDC60|160777',
#  'OR1E1|8387',
#  'FBXO30|84085',
#  'ZNF767|79970',
#  'SNTB2|6645',
#  'GRAP2|9402',
#  'RBBP6|5930',
#  'CDC25B|994',
#  'PSG4|5672',
#  'AKAP3|10566',
#  'AHSA2|130872',
#  'TMEM185A|84548',
#  'MAP1B|4131',
#  'HYAL3|8372',
#  'ADAM10|102',
#  'ENPP2|5168',
#  'ZNF441|126068',
#  'DUSP3|1845',
#  'EPHA10|284656',
#  'LOC595101|595101',
#  'CLDN16|10686',
#  'BOLA2|552900',
#  'SLC22A12|116085',
#  'HGF|3082',
#  'INTS12|57117',
#  'PRSS27|83886',
#  'SEPT14|346288',
#  'LTF|4057',
#  'VEZT|55591',
#  'RPS28|6234',
#  'GAPT|202309',
#  'ZNF439|90594',
#  'PCYT1B|9468',
#  'KRT6C|286887',
#  'FAM49B|51571',
#  'BAZ1A|11177',
#  'TMEM155|132332',
#  'C15orf2|23742',
#  'PTDSS2|81490',
#  'MCM2|4171',
#  'TBC1D21|161514',
#  'AQP7P3|441432',
#  'TSFM|10102',
#  'ZNF628|89887',
#  'TK2|7084',
#  'KLHL10|317719',
#  'GRASP|160622',
#  'SLCO4A1|28231',
#  'C19orf18|147685',
#  'PGC|5225',
#  'FAM133B|257415',
#  'HDDC2|51020',
#  'KIAA1841|84542',
#  'FAM38B|63895',
#  'DDX25|29118',
#  'SERPINE1|5054',
#  'CDO1|1036',
#  'SNORD116-4|100033416',
#  'VAMP3|9341',
#  'ZFAND1|79752',
#  'NOTO|344022',
#  'DUSP13|51207',
#  'C4orf10|317648',
#  'HIST1H2BM|8342',
#  'PTGFRN|5738',
#  'GINS1|9837',
#  'CAPN7|23473',
#  'ALDH18A1|5832',
#  'ZNF365|22891',
#  'OR8I2|120586',
#  'VENTXP7|391518',
#  'BMP4|652',
#  'TXNDC2|84203',
#  'FXR2|9513',
#  'DAOA|267012',
#  'SLC35B1|10237',
#  'PLEKHO1|51177',
#  'SH2D7|646892',
#  'TSPAN18|90139',
#  'SNORD116-14|100033426',
#  'TAF1B|9014',
#  'OR2J3|442186',
#  'ARFIP2|23647',
#  'DPYSL4|10570',
#  'PRSS55|203074',
#  'OR1J2|26740',
#  'SPRR1A|6698',
#  'CR1L|1379',
#  'THBS2|7058',
#  'C14orf93|60686',
#  'PLCXD1|55344',
#  'TP53I3|9540',
#  'SLC6A10P|386757',
#  'TMEM68|137695',
#  'LRP8|7804',
#  'UCK2|7371',
#  'WDR77|79084',
#  'ZNF304|57343',
#  'CCKAR|886',
#  'C1QBP|708',
#  'KRT33B|3884',
#  'DPPA2|151871',
#  'RABL2A|11159',
#  'TUBB6|84617',
#  'IL12A|3592',
#  'MRPS33|51650',
#  'SLCO1C1|53919',
#  'SPI1|6688',
#  'PAAF1|80227',
#  'F8A1|8263',
#  'PTPRC|5788',
#  'PTPRJ|5795',
#  'SNORA11B|100124539',
#  'CCDC130|81576',
#  'F8|2157',
#  'NBL1|4681',
#  'PCDHAC2|56134',
#  'NCRNA00032|158035',
#  'KIF21B|23046',
#  'WFDC2|10406',
#  'OAS3|4940',
#  'PRDX4|10549',
#  'C16orf46|123775',
#  'ATAD2|29028',
#  'C16orf73|254528',
#  'INHBB|3625',
#  'ARGLU1|55082',
#  'C1QB|713',
#  'ASPDH|554235',
#  'TOMM40|10452',
#  'KANK3|256949',
#  'SOCS1|8651',
#  'CCL21|6366',
#  'DUSP9|1852',
#  'FAAH2|158584',
#  'CA8|767',
#  'POLR1A|25885',
#  'HSFX2|100130086',
#  'C12orf52|84934',
#  'GAN|8139',
#  'TBC1D13|54662',
#  'LCE3E|353145',
#  'PLCD1|5333',
#  'WBP5|51186',
#  'GNPNAT1|64841',
#  'CXorf48|54967',
#  'NCRNA00112|54089',
#  'C7orf10|79783',
#  'ATG9B|285973',
#  'MSLNL|401827',
#  'TYSND1|219743',
#  'EMCN|51705',
#  'SRD5A1|6715',
#  'SLMO2|51012',
#  'PRAMEF9|343070',
#  'HGSNAT|138050',
#  'SLC28A1|9154',
#  'LRRC37A2|474170',
#  'CCDC85C|317762',
#  'A2BP1|54715',
#  'TMC2|117532',
#  'GTF2H4|2968',
#  'SERTAD4|56256',
#  'C2orf58|285154',
#  'CHMP2A|27243',
#  'SNX3|8724',
#  'C13orf26|122046',
#  'ASIP|434',
#  'C7orf30|115416',
#  'FCN2|2220',
#  'RALGPS1|9649',
#  'GAK|2580',
#  'SDC2|6383',
#  'LOC100130581|100130581',
#  'CAPN5|726',
#  'FN3KRP|79672',
#  'TUBA3C|7278',
#  'GTF2E1|2960',
#  'COX7A1|1346',
#  'MYH9|4627',
#  'CCNL1|57018',
#  ...]

# %% [markdown]
# Now we can remove all of the features idenfitied.

# %%
train_removed = fs.remove(methods = 'all')
# Out:
# ['zero_importance', 'low_importance', 'missing'] methods have been run
#
# Removed 20173 features.

# %% [markdown]
# ### Handling One-Hot Features
#
# If we look at the dataframe that is returned, we may notice several new columns that were not in the original data. These are created when the data is one-hot encoded for machine learning. To remove all the one-hot features, we can pass in `keep_one_hot = False` to the `remove` method.

# %%
train_removed_all = fs.remove(methods = 'all', keep_one_hot=False)
# Out:
# ['zero_importance', 'low_importance', 'missing'] methods have been run
#
# Removed 20173 features including one-hot features.

# %%
print('Original Number of Features', X.shape[1])
print('Final Number of Features: ', train_removed_all.shape[1])
# Out:
# Original Number of Features 20531
# Final Number of Features:  358

# %%
train_removed_all
# Out:
#       ?|100133144   ?|10431  ?|155060  ?|26823  ?|553137  ?|645851  ?|728788  \
# 0          4.4709  1224.560  110.6620   0.8078    0.0000    6.8659    0.0000
# 1          5.2474   560.474  631.1350   0.4015    0.0000    4.0149    5.2193
# 2          5.3404   629.787  216.3120   0.0000    0.0000    2.8369    0.0000
# 3          0.3247   544.805   72.0779   0.0000    0.0000   13.3117    0.0000
# 4          3.1889   771.070  275.2540   0.0000    0.0000    6.8739    0.0000
# ...           ...       ...       ...      ...       ...       ...       ...
# 1595      15.5193   873.979  256.1260   1.1669    4.0840   13.4189    0.5834
# 1596       8.4195   766.745  370.2770   0.7209    1.4417   60.5515    2.6431
# 1597      42.9857   677.733  334.7450   0.0000    0.0000   12.3641    0.0000
# 1598      14.0861  1137.320  170.8130   2.8708    4.7847   36.8421    1.4354
# 1599      20.5338   565.433  377.3920   0.6552    3.2760   15.7247    0.6552
#
#       ?|729884  ?|90288  A4GALT|53947  ...  VSIG2|23584  WDR60|55112  \
# 0       2.0194   2.4233       33.5218  ...       1.6155      309.370
# 1       0.0000   3.2119      105.1890  ...       1.2045      144.133
# 2      69.5035   4.9645      200.0000  ...      40.4255      236.879
# 3       2.5974  10.0649      141.2340  ...       0.3247      407.792
# 4       0.0000   0.5977       36.4614  ...       0.8966      368.201
# ...        ...      ...           ...  ...          ...          ...
# 1595    0.5834  15.1692      950.4080  ...    1345.9700      599.183
# 1596   18.2615  21.8658      233.0750  ...     305.4000      549.528
# 1597  168.9750  20.1488      378.2480  ...    1110.0200     2161.880
# 1598   11.4833   7.1770       56.9378  ...    1009.5700      627.751
# 1599    0.0000  36.0357      260.1130  ...    2562.4700      603.435
#
#       WFDC12|128488  WNT5A|7474  XPO1|7514  ZNF536|9745  ZNF594|84622  \
# 0            4.0388     61.7932    4022.21      16.5590       77.1405
# 1            0.0000     77.4867    3462.81       7.6282       69.8585
# 2            0.7092   2243.9700    2417.02       4.2553      110.6380
# 3            0.0000     28.8961    1666.23     485.0650      108.1170
# 4            0.0000    104.6030    3918.71       2.6898      120.7410
# ...             ...         ...        ...          ...           ...
# 1595         2.9172    266.0440    3648.19       1.1669      102.6840
# 1596         0.7209    463.2670    3833.72       0.4806      347.2100
# 1597         2.2896   1583.0600    2200.34       2.7476      102.5760
# 1598        44.0191    332.5360    3714.83       0.0000      222.0100
# 1599         0.0000    863.5470    1989.17      13.1039      191.9720
#
#       ZNF675|171392  ZNF774|342132  ZNF853|54753
# 0           58.9661         7.2698     2831.9900
# 1           87.5238         9.2342       28.9070
# 2           63.8298         9.9291      212.7660
# 3           22.7273         5.8442      381.4930
# 4           96.5332         5.6784       42.7376
# ...             ...            ...           ...
# 1595        71.7620        36.7561       80.5134
# 1596       108.3680        28.5937       90.1063
# 1597        93.8752        46.7086      284.8310
# 1598        86.6029        56.9378       67.9426
# 1599       106.7970        97.6241      191.9720
#
# [1600 rows x 358 columns]

# %%
X
# Out:
#       ?|100130426  ?|100133144  ?|100134869   ?|10357   ?|10431  ?|136542  \
# 0             0.0       4.4709       6.4338  143.5700  1224.560       0.0
# 1             0.0       5.2474       8.0016   84.6612   560.474       0.0
# 2             0.0       5.3404       3.8794  118.8790   629.787       0.0
# 3             0.0       0.3247       0.0000   92.8766   544.805       0.0
# 4             0.0       3.1889       3.3861  163.9870   771.070       0.0
# ...           ...          ...          ...       ...       ...       ...
# 1595          0.0      15.5193      22.9872  100.1870   873.979       0.0
# 1596          0.0       8.4195      10.3226   74.7210   766.745       0.0
# 1597          0.0      42.9857      81.1128   85.3715   677.733       0.0
# 1598          0.0      14.0861      24.1914   61.1388  1137.320       0.0
# 1599          0.0      20.5338       8.9500   76.9265   565.433       0.0
#
#       ?|155060  ?|26823  ?|280660  ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# 0     110.6620   0.8078    0.0000       0.0  ...    16.5590      164.782
# 1     631.1350   0.4015    0.0000       0.0  ...    46.1708      286.259
# 2     216.3120   0.0000    0.0000       0.0  ...    25.5319      234.752
# 3      72.0779   0.0000    0.6494       0.0  ...    33.4416      245.130
# 4     275.2540   0.0000    0.0000       0.0  ...    49.6115      300.060
# ...        ...      ...       ...       ...  ...        ...          ...
# 1595  256.1260   1.1669    0.0000       0.0  ...    40.8401      329.055
# 1596  370.2770   0.7209    0.0000       0.0  ...    50.6998      374.362
# 1597  334.7450   0.0000    0.0000       0.0  ...    16.9433      168.975
# 1598  170.8130   2.8708    0.0000       0.0  ...   136.3640      562.679
# 1599  377.3920   0.6552    0.0000       0.0  ...    60.2780      364.289
#
#       ZXDC|79364  ZYG11A|440590  ZYG11B|79699  ZYX|7791  ZZEF1|23140  \
# 0        773.425         7.2698       644.588   1236.27      622.779
# 1       1020.580         0.8030       690.154   3594.50      883.670
# 2       1126.240        15.6028       849.645   3270.21     1105.670
# 3       1023.700         0.0000       436.039   5132.14     1796.100
# 4        742.977         0.0000       991.632   5128.21     1097.430
# ...          ...            ...           ...       ...          ...
# 1595    1107.350        17.5029       726.371   4185.53     1333.720
# 1596    1485.430        52.6221       757.854   3077.79     1989.310
# 1597    1224.960        10.0744       531.654   1995.19     1424.160
# 1598    1296.650         0.4785       782.297   4483.25     1520.570
# 1599    1830.620         6.5520       623.091   5346.39     1582.950
#
#       ZZZ3|26009  psiTPTE22|387590  tAKR|389932
# 0        721.325            2.8271       0.0000
# 1       1137.810            4.8178       0.4015
# 2        769.504          197.1630       0.0000
# 3        286.039            2.5974       0.0000
# 4       1659.000            1.7932       0.0000
# ...          ...               ...          ...
# 1595     585.181          536.1730       0.0000
# 1596     611.762          757.3740       1.2014
# 1597     426.789            5.4951       0.0000
# 1598     477.990          186.1240       0.4785
# 1599     509.742          318.4250       0.0000
#
# [1600 rows x 20531 columns]

# %%
fs.feature_importances.sort_values('normalized_importance', ascending=False)
# Out:
#              feature  importance  normalized_importance  cumulative_importance
# 0        ?|100133144         6.7               0.104688               0.104688
# 1           KLK3|354         1.8               0.028125               0.132812
# 2       ACBD7|414149         1.6               0.025000               0.157812
# 3         SFTPB|6439         1.3               0.020313               0.178125
# 4         AACS|65985         1.2               0.018750               0.196875
# ...              ...         ...                    ...                    ...
# 20522    GDAP1|54332         0.0               0.000000               1.000000
# 20523  GDAP1L1|78997         0.0               0.000000               1.000000
# 20524        GC|2638         0.0               0.000000               1.000000
# 20525      GCSH|2653         0.0               0.000000               1.000000
# 20530    tAKR|389932         0.0               0.000000               1.000000
#
# [20531 rows x 4 columns]

# %%
flags=[10, 20, 30, 40, 50, 100, 150]
for flag in flags :
    X=train_removed_all
    y_=pd.read_csv('../tiny_labels.tsv', sep='\t')
    
    train=X.loc[:,fs.feature_importances.sort_values('importance', ascending=False)[:flag]['feature']]
    train['cancer type']=y_
    exp = train.set_index('cancer type')
    exp_s = exp.loc[['SKCM', 'PRAD', 'LUAD']]
    X = exp_s.reset_index().drop(['cancer type'], axis=1)

    y_ = exp_s.index
    lb = LabelEncoder()
    lb.fit(y_)
    y=lb.transform(y_)
    
    X.to_csv('../tiny_data_'+str(flag)+'.tsv', index=False, header=True, sep='\t')
    pd.DataFrame(y_).to_csv('../tiny_label_'+str(flag)+'.tsv', index=False, header=True, sep='\t')

# %%
for ele in fs.feature_importances.sort_values('importance', ascending=False)[:20]['feature']:
    print("'"+ele+"', ",end='')
# Out:
# '?|100133144', 'KLK3|354', 'ACBD7|414149', 'SFTPB|6439', 'AACS|65985', 'KRT8|3856', 'EPCAM|4072', 'A4GALT|53947', 'ABCC8|6833', 'TNMD|64102', 'ATP11C|286410', 'FGD6|55785', 'LEF1|51176', 'SFTA2|389376', 'QPCT|25797', 'C1orf116|79098', 'ABCB5|340273', 'RASL10A|10633', 'JUP|3728', 'RLBP1|6017',

# %%
pd.read_csv('../tiny_data_'+str(flags[6])+'.tsv', sep='\t')
# Out:
#       ?|100133144  KLK3|354  ACBD7|414149   SFTPB|6439  AACS|65985  \
# 0          4.4709    2.0194       29.8869      33.1179     975.364
# 1          5.2474    3.6134        2.8104     114.8250     140.520
# 2          5.3404   37.5887      114.8940       0.0000    1415.600
# 3          0.3247    0.0000        7.1429       0.9740     457.467
# 4          3.1889    0.0000       13.4489       0.5977     642.857
# ...           ...       ...           ...          ...         ...
# 1595      15.5193    0.0000        9.9183  280745.0000     680.280
# 1596       8.4195    0.7209       42.0496  233308.0000    2969.660
# 1597      42.9857    0.0000        8.7006  983539.0000     583.858
# 1598      14.0861    0.0000       88.5167  715604.0000    1072.730
# 1599      20.5338    0.0000       44.5533   26194.7000     847.168
#
#        KRT8|3856  EPCAM|4072  A4GALT|53947  ABCC8|6833  TNMD|64102  ...  \
# 0         4.0388      4.0388       33.5218      0.4039      0.4039  ...
# 1       555.6840      0.0000      105.1890      0.0000      0.4015  ...
# 2      3875.2400   1204.9600      200.0000      0.0000      7.8014  ...
# 3       130.5190      3.2468      141.2340      2.5974      0.3247  ...
# 4        69.9342      1.1955       36.4614      0.0000      0.0000  ...
# ...          ...         ...           ...         ...         ...  ...
# 1595  17988.4000   8288.8000      950.4080      5.2509      0.0000  ...
# 1596   9606.8500  12240.5000      233.0750    521.1750      0.0000  ...
# 1597  23991.0000   9493.7600      378.2480      0.0000      0.4579  ...
# 1598  10543.6000  12395.2000       56.9378      7.1770      0.0000  ...
# 1599  17171.6000   6745.2400      260.1130      8.5175      0.0000  ...
#
#       MAGIX|79917  ANO1|55107  NDUFB11|54539  PRSS8|5652  FAM13AOS|285512  \
# 0         27.8675   1096.1200       1889.740     14.9435          29.6648
# 1         27.7025    124.4600       1357.820      0.4015          34.4595
# 2        122.6950   5299.2900       2054.610   4207.0900          45.1560
# 3         20.4545    191.8830       2153.900     19.1558           0.8377
# 4         10.7591     72.3252       1320.680      7.1727           5.5589
# ...           ...         ...            ...         ...              ...
# 1595     313.3020    558.9270       1612.600  10460.9000          93.9965
# 1596     154.0220    408.7220       1076.230   1248.0300          76.2636
# 1597     110.3610     93.8752        878.764   5493.3000         225.0900
# 1598     433.0140    204.3060       3208.610   7212.9200          63.4737
# 1599     202.4550    425.8770       1220.630  19430.5000         124.1270
#
#       USP15|9958  EI24|9538  KLC1|3831  KIAA1324|57535  EHD2|30846
# 0        540.792    2884.89    2362.79          7.2698     306.139
# 1       1147.850    1395.56    1187.43         74.6763     572.920
# 2        548.936    2943.97    1836.08       9194.3300    1295.040
# 3         88.961    2381.17    1845.52         14.2857    4965.910
# 4        649.731    3347.58    2013.73          5.6784    7260.310
# ...          ...        ...        ...             ...         ...
# 1595     734.539    2238.62    1311.91       4105.0200    4617.270
# 1596     982.519    2484.05    2140.45       8827.0600    1918.180
# 1597     654.379    2667.43    1115.58       2207.2100    5825.760
# 1598     588.995    1962.68    1707.05       1084.6900    5184.690
# 1599     970.344    2461.57    1378.36      11277.9000    2394.740
#
# [1600 rows x 150 columns]

# %% [markdown]
# # Alternative option이 있으므로 더 자세한 것은 feature-selector github을 참고하여 사용하길 바랍니다.
#
# 2021.01.07 Jeoung Chanyoung 수정

# %% [markdown]
# # Conclusions
#
# This notebook showed how to use the `FeatureSelector` class for removing features from a dataset. There are a few important notes from this implementation:
#
# * Feature importances will change on multiple runs of the machine learning model
# * Decide whether or not to keep the extra features created from one-hot encoding
# * Try out several different values for the various parameters to decide which ones work best for a machine learning task
# * The output of missing, single unique, and collinear will stay the same for the identical parameters
# * Feature selection is a critical step of a machine learning workflow that may require several iterations to optimize
#
# I appreciate any comments, feedback, or help on this project.
#
# Will
